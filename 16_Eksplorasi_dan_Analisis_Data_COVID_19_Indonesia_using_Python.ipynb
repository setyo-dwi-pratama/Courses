# %% [markdown]
# <a href="https://colab.research.google.com/github/setyo-dwi-pratama/Courses/blob/main/16_Eksplorasi_dan_Analisis_Data_COVID_19_Indonesia_using_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Eksplorasi dan Analisis Data COVID-19 Indonesia using Python**

# %% [markdown]
# ## **Pengantar**

# %% [markdown]
# ### **Latar Belakang Project**
# COVID-19 merupakan penyakit yang saat ini telah menjadi pandemi secara global. Kondisi menjadi semakin mengkhawatirkan karena hingga detik ini masih belum ditemukan vaksin yang efektif untuk virus penyebab COVID-19. Pemerintah di berbagai negara umumnya dengan sigap membentuk gugus tugas (task force unit) untuk menangani penyebaran COVID-19 di masyarakat, termasuk pemerintah di Indonesia.
#
# Salah satu bentuk aksi yang dilakukan oleh pemerintah adalah dengan mengumpulkan dan menyediakan data pertumbuhan kasus COVID-19 kepada publik. Data pertumbuhan kasus tersebut tidak jarang juga dilengkapi dengan dasbor dan grafik visualisasi pendukung dengan harapan masyarakat dapat memahami informasi dengan lebih mudah. Sebagai contoh adalah portal **covid19.go.id** besutan Gugus Tugas Penanganan COVID-19 Nasional dan portal **PIKOBAR** milik pemerintah Provinsi Jawa Barat. Serta banyak portal data COVID-19 lainnya yang disediakan oleh masing-masing pemerintah daerah.

# %% [markdown]
# ### **Warming Up!**
# Sebagai pemanasan sebelum Anda memulai proyek ini, buatlah sebuah vektor karakter dengan 3 elemen dengan nama bersatulawancovid yang merupakan kunci dasar menghindari COVID-19! Jangan lupa untuk mencetak vektor bersatulawancovid tersebut pada layar konsol!

# %%
bersatulawancovid = ['cuci tangan', 'pakai masker', 'jaga jarak']
print(bersatulawancovid)
# Out:
# ['cuci tangan', 'pakai masker', 'jaga jarak']

# %% [markdown]
# ### **Are You Ready?**
# Dalam proyek ini, Anda akan diminta untuk melakukan eksplorasi dan analisis mengenai COVID-19 di Indonesia. Data yang Anda pergunakan diambil langsung dari **API (Application Programming Interface)** yang tersedia di **covid19.go.id**.
#
# Sehingga dalam proyek ini Anda akan mempelajari **teknik mengambil data** dari API, **teknik mempersiapkan data**, serta **analisis dan visualisasi data**.

# %% [markdown]
# ## **Bermain API**

# %% [markdown]
# ### **Mengakses API covid19.go.id**
# Rekapitulasi data COVID-19 Indonesia tersedia dalam API publik yang beralamat di https://data.covid19.go.id/public/api/update.json.
#
# Salah satu cara untuk mengakses API adalah dengan menggunakan fungsi **get()** dari **library requests**.
#
# Sekarang aktifkanlah **library requests** dan jalankan fungsi **get()** pada alamat API yang telah disebutkan!
#
# Simpan hasil fungsi tersebut dalam obyek bernama **resp**.

# %%
import requests
resp = requests.get('https://data.covid19.go.id/public/api/update.json')

# %% [markdown]
# ### **Mengevaluasi Respon**
# Saat Anda menjalankan fungsi **get()**, pada dasarnya hal yang terjadi adalah Anda membuat sebuah permintaan kepada server penyedia API.
#
# Permintaan Anda tersebut selanjutnya diproses dan dijawab oleh server sebagai sebuah respon. Objek **resp** yang telah Anda buat memiliki informasi respon oleh server.
#
# Ada tiga informasi utama dalam sebuah respon API, yaitu **status, headers, dan body**.
#
# **Status** memiliki informasi apakah permintaan Anda berhasil atau tidak dan dinyatakan dalam status code.
#
# **headers** umumnya mengandung informasi metadata
#
# sedangkan **body** berisikan konten atas permintaan yang telah dibuat.

# %% [markdown]
# ### **Status Code**
# Ada beberapa jenis status code yang umumnya dijumpai, antara lain:
#
# * 200 Artinya permintaan sukses dipenuhi.
# * 404 Artinya berkas yang diminta tidak dapat ditemukan.
# * 500 Artinya akses permintaan ditolak.
# * 501 Artinya terjadi kesalahan pada server.
#
# Informasi lengkap mengenai jenis-jenis status code dapat Anda pelajari di https://restfulapi.net/http-status-codes/
#
# Anda dapat **mencetak resp** secara langsung yang telah memberikan output status atas permintaan Anda melalui API. Sekarang coba lihatlah status atas permintaan yang telah Anda buat! Apakah permintaan Anda berhasil?

# %%
print(resp)
# Out:
# <Response [200]>

# %% [markdown]
# ### **Headers API**
# Selamat status permintaan Anda melalui API sukses dipenuhi! Sekarang cobalah Anda **jalankan attribut headers** pada resp untuk mengetahui metadata apa saja yang tersimpan. Tampilkan dengan menggunakan fungsi print.
#
# Apakah isi dari elemen content-type?
#
# Kapan terakhir kali informasi diperbaharui?

# %%
print(resp.headers)
# Out:
# {'Server': 'nginx', 'Date': 'Fri, 19 Feb 2021 06:08:48 GMT', 'Content-Type': 'application/json', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Vary': 'Accept-Encoding, Accept-Encoding', 'Last-Modified': 'Fri, 19 Feb 2021 06:05:08 GMT', 'ETag': 'W/"602f5514-2134a"', 'X-Content-Type-Options': 'nosniff, nosniff', 'X-XSS-Protection': '1; mode=block, 1; mode=block', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload', 'Content-Encoding': 'gzip'}

# %% [markdown]
# ### **Mengekstrak Isi Respon**
# Respon API dengan status code **200** menyatakan bahwa permintaan Anda berhasil dipenuhi dan konten yang diminta tersedia untuk diekstrak. Selain itu Anda juga telah mengetahui lewat attribut **headers** bahwa konten yang diminta tersedia dalam bentuk **application/json**, yaitu berkas **JSON**.
#
# Selanjutnya Anda dapat mengekstrak konten tersebut dengan menggunakan method json(). **Method json()** merupakan builtin JSON decoder untuk mengekstrak content bertipe JSON. Anda juga dapat menggunakan attribut content tetapi ini berupa binary **content** yang perlu Anda proses kembali nantinya. Jalankan method **json()** pada obyek **resp** dan simpanlah hasilnya sebagai **cov_id_raw**!
#
# cov_id_raw ini **bertipe data dict**.

# %%
cov_id_raw = resp.json()
cov_id_raw
# Out:
# {'data': {'id': 1,
#   'jumlah_odp': 82444,
#   'jumlah_pdp': 0,
#   'total_spesimen': 10188747,
#   'total_spesimen_negatif': 5514541},
#  'update': {'harian': [{'doc_count': 1,
#     'jumlah_dirawat': {'value': 2},
#     'jumlah_dirawat_kum': {'value': 2},
#     'jumlah_meninggal': {'value': 0},
#     'jumlah_meninggal_kum': {'value': 0},
#     'jumlah_positif': {'value': 2},
#     'jumlah_positif_kum': {'value': 2},
#     'jumlah_sembuh': {'value': 0},
#     'jumlah_sembuh_kum': {'value': 0},
#     'key': 1583107200000,
#     'key_as_string': '2020-03-02T00:00:00.000Z'},
#    {'doc_count': 1,
#     'jumlah_dirawat': {'value': 0},
#     'jumlah_dirawat_kum': {'value': 2},
#     'jumlah_meninggal': {'value': 0},
#     'jumlah_meninggal_kum': {'value': 0},
#     'jumlah_positif': {'value': 0},
#     'jumlah_positif_kum': {'value': 2},
#     'jumlah_sembuh': {'value': 0},
#     'jumlah_sembuh_kum': {'value': 0},
#     'key': 1583193600000,
#     'key_as_string': '2020-03-03T00:00:00.000Z'},
#    {'doc_count': 1,
#     'jumlah_dirawat': {'value': 0},
#     'jumlah_dirawat_kum': {'value': 2},
#     'jumlah_meninggal': {'value': 0},
#     'jumlah_meninggal_kum': {'value': 0},
#     'jumlah_positif': {'value': 0},
#     'jumlah_positif_kum': {'value': 2},
#     'jumlah_sembuh': {'value': 0},
#     'jumlah_sembuh_kum': {'value': 0},
#     'key': 1583280000000,
#     'key_as_string': '2020-03-04T00:00:00.000Z'},
#    {'doc_count': 1,
#     'jumlah_dirawat': {'value': 0},
#     'jumlah_dirawat_kum': {'value': 2},
#     'jumlah_meninggal': {'value': 0},
#     'jumlah_meninggal_kum': {'value': 0},
#     'jumlah_positif': {'value': 0},
#     'jumlah_positif_kum': {'value': 2},
#     'jumlah_sembuh': {'value': 0},
#     'jumlah_sembuh_kum': {'value': 0},
#     'key': 1583366400000,
#     'key_as_string': '2020-03-05T00:00:00.000Z'},
#    {'doc_count': 1,
#     'jumlah_dirawat': {'value': 2},
#     'jumlah_dirawat_kum': {'value': 4},
#     'jumlah_meninggal': {'value': 0},
#     'jumlah_meninggal_kum': {'value': 0},
#     'jumlah_positif': {'value': 2},
#     'jumlah_positif_kum': {'value': 4},
#     'jumlah_sembuh': {'value': 0},
#     'jumlah_sembuh_kum': {'value': 0},
#     'key': 1583452800000,
#     'key_as_string': '2020-03-06T00:00:00.000Z'},
#    {'doc_count': 1,
#     'jumlah_dirawat': {'value': 0},
#     'jumlah_dirawat_kum': {'value': 4},
#     'jumlah_meninggal': {'value': 0},
#     'jumlah_meninggal_kum': {'value': 0},
#     'jumlah_positif': {'value': 0},
#     'jumlah_positif_kum': {'value': 4},
#     'jumlah_sembuh': {'value': 0},
#     'jumlah_sembuh_kum': {'value': 0},
#     'key': 1583539200000,
#     'key_as_string': '2020-03-07T00:00:00.000Z'},
#    {'doc_count': 1,
#     'jumlah_dirawat': {'value': 2},
#     'jumlah_dirawat_kum': {'value': 6},
#     'jumlah_meninggal': {'value': 0},
#     'jumlah_meninggal_kum': {'value': 0},
#     'jumlah_positif': {'value': 2},
#     'jumlah_positif_kum': {'value': 6},
#     'jumlah_sembuh': {'value': 0},
#     'jumlah_sembuh_kum': {'value': 0},
#     'key': 1583625600000,
#     'key_as_string': '2020-03-08T00:00:00.000Z'},
#    {'doc_count': 1,
#     'jumlah_dirawat': {'value': 13},
#     'jumlah_dirawat_kum': {'value': 19},
#     'jumlah_meninggal': {'value': 0},
#     'jumlah_meninggal_kum': {'value': 0},
#     'jumlah_positif': {'value': 13},
#     'jumlah_positif_kum': {'value': 19},
#     'jumlah_sembuh': {'value': 0},
#     'jumlah_sembuh_kum': {'value': 0},
#     'key': 1583712000000,
#     'key_as_string': '2020-03-09T00:00:00.000Z'},
#    {'doc_count': 1,
#     'jumlah_dirawat': {'value': 6},
#     'jumlah_dirawat_kum': {'value': 25},
#     'jumlah_meninggal': {'value': 0},
#     'jumlah_meninggal_kum': {'value': 0},
#     'jumlah_positif': {'value': 8},
#     'jumlah_positif_kum': {'value': 27},
#     'jumlah_sembuh': {'value': 2},
#     'jumlah_sembuh_kum': {'value': 2},
#     'key': 1583798400000,
#     'key_as_string': '2020-03-10T00:00:00.000Z'},
#    {'doc_count': 1,
#     'jumlah_dirawat': {'value': 6},
#     'jumlah_dirawat_kum': {'value': 31},
#     'jumlah_meninggal': {'value': 1},
#     'jumlah_meninggal_kum': {'value': 1},
#     'jumlah_positif': {'value': 7},
#     'jumlah_positif_kum': {'value': 34},
#     'jumlah_sembuh': {'value': 0},
#     'jumlah_sembuh_kum': {'value': 2},
#     'key': 1583884800000,
#     'key_as_string': '2020-03-11T00:00:00.000Z'},
#    {'doc_count': 1,
#     'jumlah_dirawat': {'value': 0},
#     'jumlah_dirawat_kum': {'value': 31},
#     'jumlah_meninggal': {'value': 0},
#     'jumlah_meninggal_kum': {'value': 1},
#     'jumlah_positif': {'value': 0},
#     'jumlah_positif_kum': {'value': 34},
#     'jumlah_sembuh': {'value': 0},
#     'jumlah_sembuh_kum': {'value': 2},
#     'key': 1583971200000,
#     'key_as_string': '2020-03-12T00:00:00.000Z'},
#    {'doc_count': 1,
#     'jumlah_dirawat': {'value': 32},
#     'jumlah_dirawat_kum': {'value': 63},
#     'jumlah_meninggal': {'value': 3},
#     'jumlah_meninggal_kum': {'value': 4},
#     'jumlah_positif': {'value': 35},
#     'jumlah_positif_kum': {'value': 69},
#     'jumlah_sembuh': {'value': 0},
#     'jumlah_sembuh_kum': {'value': 2},
#     'key': 1584057600000,
#     'key_as_string': '2020-03-13T00:00:00.000Z'},
#    {'doc_count': 1,
#     'jumlah_dirawat': {'value': 20},
#     'jumlah_dirawat_kum': {'value': 83},
#     'jumlah_meninggal': {'value': 1},
#     'jumlah_meninggal_kum': {'value': 5},
#     'jumlah_positif': {'value': 27},
#     'jumlah_positif_kum': {'value': 96},
#     'jumlah_sembuh': {'value': 6},
#     'jumlah_sembuh_kum': {'value': 8},
#     'key': 1584144000000,
#     'key_as_string': '2020-03-14T00:00:00.000Z'},
#    {'doc_count': 1,
#     'jumlah_dirawat': {'value': 21},
#     'jumlah_dirawat_kum': {'value': 104},
#     'jumlah_meninggal': {'value': 0},
#     'jumlah_meninggal_kum': {'value': 5},
#     'jumlah_positif': {'value': 21},
#     'jumlah_positif_kum': {'value': 117},
#     'jumlah_sembuh': {'value': 0},
#     'jumlah_sembuh_kum': {'value': 8},
#     'key': 1584230400000,
#     'key_as_string': '2020-03-15T00:00:00.000Z'},
#    {'doc_count': 1,
#     'jumlah_dirawat': {'value': 17},
#     'jumlah_dirawat_kum': {'value': 121},
#     'jumlah_meninggal': {'value': 0},
#     'jumlah_meninggal_kum': {'value': 5},
#     'jumlah_positif': {'value': 17},
#     'jumlah_positif_kum': {'value': 134},
#     'jumlah_sembuh': {'value': 0},
#     'jumlah_sembuh_kum': {'value':
00:00:00.000Z'},
#    {'doc_count': 1,
#     'jumlah_dirawat': {'value': 1493},
#     'jumlah_dirawat_kum': {'value': 162182},
#     'jumlah_meninggal': {'value': 192},
#     'jumlah_meninggal_kum': {'value': 33788},
#     'jumlah_positif': {'value': 9687},
#     'jumlah_positif_kum': {'value': 1243646},
#     'jumlah_sembuh': {'value': 8002},
#     'jumlah_sembuh_kum': {'value': 1047676},
#     'key': 1613520000000,
#     'key_as_string': '2021-02-17T00:00:00.000Z'},
#    {'doc_count': 1,
#     'jumlah_dirawat': {'value': -1688},
#     'jumlah_dirawat_kum': {'value': 160494},
#     'jumlah_meninggal': {'value': 181},
#     'jumlah_meninggal_kum': {'value': 33969},
#     'jumlah_positif': {'value': 9039},
#     'jumlah_positif_kum': {'value': 1252685},
#     'jumlah_sembuh': {'value': 10546},
#     'jumlah_sembuh_kum': {'value': 1058222},
#     'key': 1613606400000,
#     'key_as_string': '2021-02-18T00:00:00.000Z'}],
#   'penambahan': {'created': '2021-02-18 16:26:47',
#    'jumlah_dirawat': -1688,
#    'jumlah_meninggal': 181,
#    'jumlah_positif': 9039,
#    'jumlah_sembuh': 10546,
#    'tanggal': '2021-02-18'},
#   'total': {'jumlah_dirawat': 160494,
#    'jumlah_meninggal': 33969,
#    'jumlah_positif': 1252685,
#    'jumlah_sembuh': 1058222}}}

# %% [markdown]
# ### **Mengekstrak isi Respon - 2**
# Dengan menggunakan fungsi **len()** dan method **keys()** cobalah amati ada berapa komponen serta apa saja nama komponen dalam obyek **cov_id_raw** tersebut! Kemudian ekstraklah key ke-2 dan simpan dengan nama **cov_id_update**.

# %%
print('Length of cov_id_raw : %d.' %len(cov_id_raw))
print('Komponen cov_id_raw : %s.' %cov_id_raw.keys())
cov_id_update = cov_id_raw['update']
# Out:
# Length of cov_id_raw : 2.
# Komponen cov_id_raw : dict_keys(['data', 'update']).

# %% [markdown]
# ### **Analisa Data**
# Sekarang Anda diminta untuk fokus pada obyek **cov_id_update** untuk menjawab pertanyaan-pertanyaan berikut:
#
# * Kapan tanggal pembaharuan data penambahan kasus?
# * Berapa jumlah penambahan kasus sembuh?
# * Berapa jumlah penambahan kasus meninggal?
# * Berapa jumlah total kasus positif hingga saat ini?
# * Berapa jumlah total kasus meninggal hingga saat ini?

# %%
print('Tanggal pembaharuan data penambahan kasus :', cov_id_update['penambahan']['tanggal'])
print('Jumlah penambahan kasus sembuh :', cov_id_update['penambahan']['jumlah_sembuh'])
print('Jumlah penambahan kasus meninggal :', cov_id_update['penambahan']['jumlah_meninggal'])
print('Jumlah total kasus positif hingga saat ini :', cov_id_update['total']['jumlah_positif'])
print('Jumlah total kasus meninggal hingga saat ini:', cov_id_update['total']['jumlah_meninggal'])
# Out:
# Tanggal pembaharuan data penambahan kasus : 2021-02-18
# Jumlah penambahan kasus sembuh : 10546
# Jumlah penambahan kasus meninggal : 181
# Jumlah total kasus positif hingga saat ini : 1252685
# Jumlah total kasus meninggal hingga saat ini: 33969

# %% [markdown]
# ## **COVID-19 Di Sekitar**

# %% [markdown]
# ### **Apa Kabar Jawa Barat?**
# Anda telah berhasil menjawab pertanyaan mengenai kondisi COVID-19 di Indonesia dengan menggunakan data yang langsung diambil menggunakan API. Namun bagaimana jika Anda ingin berfokus dengan data COVID-19 di provinsi tempat menetap saat ini?

# %% [markdown]
# **covid19.go.id** menyediakan data kasus COVID-19 tingkat provinsi di alamat API yang berbeda. Sebagai data mengenai **COVID-19 Jawa Barat**, tempat tinggal saya sekarang, tersedia di https://data.covid19.go.id/public/api/prov_detail_JAWA_BARAT.json.

# %%
import requests
resp_jabar = requests.get('https://data.covid19.go.id/public/api/prov_detail_JAWA_BARAT.json')
cov_jabar_raw = resp_jabar.json()
cov_jabar_raw
# Out:
# {'data': {'kasus': {'gejala': {'current_data': 948,
#     'list_data': [{'doc_count': 66.03375527426161, 'key': 'BATUK'},
#      {'doc_count': 46.20253164556962, 'key': 'PILEK'},
#      {'doc_count': 41.244725738396625, 'key': 'RIWAYAT DEMAM'},
#      {'doc_count': 33.22784810126582, 'key': 'DEMAM'},
#      {'doc_count': 26.265822784810126, 'key': 'SESAK NAPAS'},
#      {'doc_count': 25.31645569620253, 'key': 'SAKIT TENGGOROKAN'},
#      {'doc_count': 24.47257383966245, 'key': 'SAKIT KEPALA'},
#      {'doc_count': 23.945147679324894, 'key': 'LEMAS'},
#      {'doc_count': 16.9831223628692, 'key': 'KERAM OTOT'},
#      {'doc_count': 14.029535864978904, 'key': 'MUAL'},
#      {'doc_count': 7.2784810126582276, 'key': 'SAKIT PERUT'},
#      {'doc_count': 5.274261603375527, 'key': 'DIARE'},
#      {'doc_count': 3.2700421940928273, 'key': 'MENGGIGIL'}],
#     'missing_data': 99.46121057118499},
#    'jenis_kelamin': {'current_data': 170778,
#     'list_data': [{'doc_count': 48.86929229760273, 'key': 'LAKI-LAKI'},
#      {'doc_count': 51.13070770239726, 'key': 'PEREMPUAN'}],
#     'missing_data': 2.9394714407502107},
#    'kelompok_umur': {'current_data': 169649,
#     'list_data': [{'doc_count': 3.4052661672040503,
#       'key': '0-5',
#       'usia': {'value': 5.0}},
#      {'doc_count': 11.781383916203456, 'key': '6-18', 'usia': {'value': 18.0}},
#      {'doc_count': 24.829500910703864,
#       'key': '19-30',
#       'usia': {'value': 30.0}},
#      {'doc_count': 28.835419012195768,
#       'key': '31-45',
#       'usia': {'value': 45.0}},
#      {'doc_count': 21.922321970657062,
#       'key': '46-59',
#       'usia': {'value': 59.0}},
#      {'doc_count': 9.226108023035797,
#       'key': '≥ 60',
#       'usia': {'value': 9783561644.0}}],
#     'missing_data': 3.58113100312589},
#    'kondisi_penyerta': {'current_data': 187,
#     'list_data': [{'doc_count': 50.80213903743316, 'key': 'HIPERTENSI'},
#      {'doc_count': 26.203208556149733, 'key': 'DIABETES MELITUS'},
#      {'doc_count': 21.390374331550802, 'key': 'PENYAKIT JANTUNG'},
#      {'doc_count': 11.229946524064172, 'key': 'HAMIL'},
#      {'doc_count': 10.695187165775401, 'key': 'GANGGUAN NAPAS LAIN'},
#      {'doc_count': 5.347593582887701,
#       'key': 'PENYAKIT PARU OBSTRUKTIF KRONIS'},
#      {'doc_count': 2.13903743315508, 'key': 'PENYAKIT GINJAL'},
#      {'doc_count': 1.6042780748663104, 'key': 'ASMA'},
#      {'doc_count': 1.6042780748663104, 'key': 'GANGGUAN IMUN'},
#      {'doc_count': 1.6042780748663104, 'key': 'KANKER'},
#      {'doc_count': 1.06951871657754, 'key': 'PENYAKIT HATI'}],
#     'missing_data': 99.89371980676329}},
#   'last_update': '2021-02-15',
#   'meninggal': {'gejala': {'list_data': [{'doc_count': 5.590717299578059,
#       'key': 'BATUK'},
#      {'doc_count': 5.485232067510549, 'key': 'SESAK NAPAS'},
#      {'doc_count': 4.957805907172996, 'key': 'DEMAM'},
#      {'doc_count': 4.430379746835443, 'key': 'RIWAYAT DEMAM'},
#      {'doc_count': 4.324894514767933, 'key': 'LEMAS'},
#      {'doc_count': 3.691983122362869, 'key': 'SAKIT TENGGOROKAN'},
#      {'doc_count': 2.7426160337552745, 'key': 'PILEK'},
#      {'doc_count': 2.320675105485232, 'key': 'SAKIT KEPALA'},
#      {'doc_count': 2.109704641350211, 'key': 'KERAM OTOT'},
#      {'doc_count': 1.6877637130801686, 'key': 'MUAL'},
#      {'doc_count': 1.0548523206751055, 'key': 'MENGGIGIL'},
#      {'doc_count': 0.6329113924050633, 'key': 'SAKIT PERUT'},
#      {'doc_count': 0.5274261603375527, 'key': 'DIARE'}]},
#    'jenis_kelamin': {'list_data': [{'doc_count': 56.19637750238322,
#       'key': 'LAKI-LAKI'},
#      {'doc_count': 43.80362249761678, 'key': 'PEREMPUAN'}]},
#    'kelompok_umur': {'list_data': [{'doc_count': 1.3062409288824384,
#       'key': '0-5',
#       'usia': {'value': 5.0}},
#      {'doc_count': 1.3546202225447508, 'key': '6-18', 'usia': {'value': 18.0}},
#      {'doc_count': 5.176584421867441, 'key': '19-30', 'usia': {'value': 30.0}},
#      {'doc_count': 15.965166908563136,
#       'key': '31-45',
#       'usia': {'value': 45.0}},
#      {'doc_count': 38.70343492985002, 'key': '46-59', 'usia': {'value': 59.0}},
#      {'doc_count': 37.49395258829221,
#       'key': '≥ 60',
#       'usia': {'value': 2020.0}}]},
#    'kondisi_penyerta': {'list_data': [{'doc_count': 8.02139037433155,
#       'key': 'HIPERTENSI'},
#      {'doc_count': 7.4866310160427805, 'key': 'DIABETES MELITUS'},
#      {'doc_count': 7.4866310160427805, 'key': 'PENYAKIT JANTUNG'},
#      {'doc_count': 5.347593582887701, 'key': 'GANGGUAN NAPAS LAIN'},
#      {'doc_count': 2.13903743315508, 'key': 'PENYAKIT PARU OBSTRUKTIF KRONIS'},
#      {'doc_count': 1.6042780748663104, 'key': 'PENYAKIT GINJAL'},
#      {'doc_count': 1.06951871657754, 'key': 'ASMA'},
#      {'doc_count': 1.06951871657754, 'key': 'HAMIL'},
#      {'doc_count': 1.06951871657754, 'key': 'KANKER'}]}},
#   'perawatan': {'gejala': {'list_data': [{'doc_count': 2.109704641350211,
#       'key': 'BATUK'},
#      {'doc_count': 1.7932489451476792, 'key': 'PILEK'},
#      {'doc_count': 1.5822784810126582, 'key': 'RIWAYAT DEMAM'},
#      {'doc_count': 1.160337552742616, 'key': 'SAKIT KEPALA'},
#      {'doc_count': 1.0548523206751055, 'key': 'SAKIT TENGGOROKAN'},
#      {'doc_count': 0.949367088607595, 'key': 'SESAK NAPAS'},
#      {'doc_count': 0.6329113924050633, 'key': 'KERAM OTOT'},
#      {'doc_count': 0.5274261603375527, 'key': 'LEMAS'},
#      {'doc_count': 0.31645569620253167, 'key': 'DIARE'},
#      {'doc_count': 0.21097046413502107, 'key': 'DEMAM'},
#      {'doc_count': 0.21097046413502107, 'key': 'MUAL'},
#      {'doc_count': 0.10548523206751054, 'key': 'SAKIT PERUT'}]},
#    'jenis_kelamin': {'list_data': [{'doc_count': 47.88992478493897,
#       'key': 'LAKI-LAKI'},
#      {'doc_count': 52.11007521506102, 'key': 'PEREMPUAN'}]},
#    'kelompok_umur': {'list_data': [{'doc_count': 3.052151988322201,
#       'key': '0-5',
#       'usia': {'value': 5.0}},
#      {'doc_count': 10.961206705887557, 'key': '6-18', 'usia': {'value': 18.0}},
#      {'doc_count': 26.05830052638563, 'key': '19-30', 'usia': {'value': 30.0}},
#      {'doc_count': 28.63272437740523, 'key': '31-45', 'usia': {'value': 45.0}},
#      {'doc_count': 21.745477064626, 'key': '46-59', 'usia': {'value': 59.0}},
#      {'doc_count': 9.55013933737338,
#       'key': '≥ 60',
#       'usia': {'value': 2019.0}}]},
#    'kondisi_penyerta': {'list_data': [{'doc_count': 2.6737967914438503,
#       'key': 'HIPERTENSI'},
#      {'doc_count': 2.6737967914438503, 'key': 'PENYAKIT JANTUNG'},
#      {'doc_count': 0.53475935828877, 'key': 'HAMIL'},
#      {'doc_count': 0.53475935828877, 'key': 'KANKER'}]}},
#   'sembuh': {'gejala': {'list_data': [{'doc_count': 58.333333333333336,
#       'key': 'BATUK'},
#      {'doc_count': 41.66666666666667, 'key': 'PILEK'},
#      {'doc_count': 35.232067510548525, 'key': 'RIWAYAT DEMAM'},
#      {'doc_count': 28.059071729957807, 'key': 'DEMAM'},
#      {'doc_count': 20.991561181434598, 'key': 'SAKIT KEPALA'},
#      {'doc_count': 20.569620253164558, 'key': 'SAKIT TENGGOROKAN'},
#      {'doc_count': 19.831223628691983, 'key': 'SESAK NAPAS'},
#      {'doc_count': 19.09282700421941, 'key': 'LEMAS'},
#      {'doc_count': 14.240506329113925, 'key': 'KERAM OTOT'},
#      {'doc_count': 12.130801687763713, 'key': 'MUAL'},
#      {'doc_count': 6.5400843881856545, 'key': 'SAKIT PERUT'},
#      {'doc_count': 4.430379746835443, 'key': 'DIARE'},
#      {'doc_count': 2.2151898734177213, 'key': 'MENGGIGIL'}]},
#    'jenis_kelamin': {'list_data': [{'doc_count': 48.91279859636666,
#       'key': 'LAKI-LAKI'},
#      {'doc_count': 51.08720140363333, 'key': 'PEREMPUAN'}]},
#    'kelompok_umur': {'list_data': [{'doc_count': 3.4902569408518715,
#       'key': '0-5',
#       'usia': {'value': 5.0}},
#      {'doc_count': 12.057941024314538, 'key': '6-18', 'usia': {'value': 18.0}},
#      {'doc_count': 24.918089325745818,
#       'key': '19-30',
#       'usia': {'value': 30.0}},
#      {'doc_count': 29.050525952750473,
#       'key': '31-45',
#       'usia': {'value': 45.0}},
#      {'doc_count': 21.710639765476806,
#       'key': '46-59',
#       'usia': {'value': 59.0}},
#      {'doc_count': 8.772546990860492,
#       'key': '≥ 60',
#       'usia': {'value': 9783561644.0}}]},
#    'kondisi_penyerta': {'list_data': [{'doc_count': 40.106951871657756,
#       'key': 'HIPERTENSI'},
#      {'doc_count': 18.71657754010695, 'key': 'DIABETES MELITUS'},
#      {'doc_count': 11.229946524064172, 'key': 'PENYAKIT JANTUNG'},
#      {'doc_count': 9.62566844919786, 'key': 'HAMIL'},
#      {'doc_count': 5.347593582887701, 'key': 'GANGGUAN NAPAS LAIN'},
#      {'doc_count': 3.2085561497326207,
#       'key': 'PENYAKIT PARU OBSTRUKTIF KRONIS'},
#      {'doc_count': 1.6042780748663104, 'key': 'GANGGUAN IMUN'},
#      {'doc_count': 1.06951871657754, 'key': 'PENYAKIT HATI'},
#      {'doc_count': 0.53475935828877, 'key': 'ASMA'},
#      {'doc_count': 0.53475935828877, 'key': 'PENYAKIT GINJAL'}]}}},
#  'kasus_dengan_tgl': 175941,
#  'kasus_tanpa_tgl': 9,
#  'kasus_total': 175950,
#  'last_date': '2021-02-15',
#  'list_perkembangan': [{'AKUMULASI_DIRAWAT_OR_ISOLASI': 3,
#    'AKUMULASI_KASUS': 3,
#    'AKUMULASI_MENINGGAL': 0,
#    'AKUMULASI_SEMBUH': 0,
#    'DIRAWAT_OR_ISOLASI': 3,
#    'KASUS': 3,
#    'MENINGGAL': 0,
#    'SEMBUH': 0,
#    'tanggal': 1583107200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 3,
#    'AKUMULASI_KASUS': 4,
#    'AKUMULASI_MENINGGAL': 1,
#    'AKUMULASI_SEMBUH': 0,
#    'DIRAWAT_OR_ISOLASI': 0,
#    'KASUS': 1,
#    'MENINGGAL': 1,
#    'SEMBUH': 0,
#    'tanggal': 1583193600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 4,
#    'AKUMULASI_KASUS': 5,
#    'AKUMULASI_MENINGGAL': 1,
#    'AKUMULASI_SEMBUH': 0,
#    'DIRAWAT_OR_ISOLASI': 1,
#    'KASUS': 1,
#    'MENINGGAL': 0,
#    'SEMBUH': 0,
#    'tanggal': 1583280000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 5,
#    'AKUMULASI_KASUS': 6,
#    'AKUMULASI_MENINGGAL': 1,
#    'AKUMULASI_SEMBUH': 0,
#    'DIRAWAT_OR_ISOLASI': 1,
#    'KASUS': 1,
#    'MENINGGAL': 0,
#    'SEMBUH': 0,
#    'tanggal': 1583366400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 6,
#    'AKUMULASI_KASUS': 7,
#    'AKUMULASI_MENINGGAL': 1,
#    'AKUMULASI_SEMBUH': 0,
#    'DIRAWAT_OR_ISOLASI': 1,
#    'KASUS': 1,
#    'MENINGGAL': 0,
#    'SEMBUH': 0,
#    'tanggal': 1583452800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 6,
#    'AKUMULASI_KASUS': 7,
#    'AKUMULASI_MENINGGAL': 1,
#    'AKUMULASI_SEMBUH': 0,
#    'DIRAWAT_OR_ISOLASI': 0,
#    'KASUS': 0,
#    'MENINGGAL': 0,
#    'SEMBUH': 0,
#    'tanggal': 1583539200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 6,
#    'AKUMULASI_KASUS': 7,
#    'AKUMULASI_MENINGGAL': 1,
#    'AKUMULASI_SEMBUH': 0,
#    'DIRAWAT_OR_ISOLASI': 0,
#    'KASUS': 0,
#    'MENINGGAL': 0,
#    'SEMBUH': 0,
#    'tanggal': 1583625600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 6,
#    'AKUMULASI_KASUS': 7,
#    'AKUMULASI_MENINGGAL': 1,
#    'AKUMULASI_SEMBUH': 0,
#    'DIRAWAT_OR_ISOLASI': 0,
#    'KASUS': 0,
#    'MENINGGAL': 0,
#    'SEMBUH': 0,
#    'tanggal': 1583712000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 6,
#    'AKUMULASI_KASUS': 7,
#    'AKUMULASI_MENINGGAL': 1,
#    'AKUMULASI_SEMBUH': 0,
#    'DIRAWAT_OR_ISOLASI': 0,
#    'KASUS': 0,
#    'MENINGGAL': 0,
#    'SEMBUH': 0,
#    'tanggal': 1583798400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 5,
#    'AKUMULASI_KASUS': 7,
#    'AKUMULASI_MENINGGAL': 2,
#    'AKUMULASI_SEMBUH': 0,
#    'DIRAWAT_OR_ISOLASI': -1,
#    'KASUS': 0,
#    'MENINGGAL': 1,
#    'SEMBUH': 0,
#    'tanggal': 1583884800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 6,
#    'AKUMULASI_KASUS': 8,
#    'AKUMULASI_MENINGGAL': 2,
#    'AKUMULASI_SEMBUH': 0,
#    'DIRAWAT_OR_ISOLASI': 1,
#    'KASUS': 1,
#    'MENINGGAL': 0,
#    'SEMBUH': 0,
#    'tanggal': 1583971200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 6,
#    'AKUMULASI_KASUS': 12,
#    'AKUMULASI_MENINGGAL': 2,
#    'AKUMULASI_SEMBUH': 4,
#    'DIRAWAT_OR_ISOLASI': 0,
#    'KASUS': 4,
#    'MENINGGAL': 0,
#    'SEMBUH': 4,
#    'tanggal': 1584057600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 6,
#    'AKUMULASI_KASUS': 12,
#    'AKUMULASI_MENINGGAL': 2,
#    'AKUMULASI_SEMBUH': 4,
#    'DIRAWAT_OR_ISOLASI': 0,
#    'KASUS': 0,
#    'MENINGGAL': 0,
#    'SEMBUH': 0,
#    'tanggal': 1584144000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 6,
#    'AKUMULASI_KASUS': 12,
#    'AKUMULASI_MENINGGAL': 2,
#    'AKUMULASI_SEMBUH': 4,
#    'DIRAWAT_OR_ISOLASI': 0,
#    'KASUS': 0,
#    'MENINGGAL': 0,
#    'SEMBUH': 0,
#    'tanggal': 1584230400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 7,
#    'AKUMULASI_KASUS': 13,
#    'AKUMULASI_MENINGGAL': 2,
#    'AKUMULASI_SEMBUH': 4,
#    'DIRAWAT_OR_ISOLASI': 1,
#    'KASUS': 1,
#    'MENINGGAL': 0,
#    'SEMBUH': 0,
#    'tanggal': 1584316800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 18,
#    'AKUMULASI_KASUS': 24,
#    'AKUMULASI_MENINGGAL': 2,
#    'AKUMULASI_SEMBUH': 4,
#    'DIRAWAT_OR_ISOLASI': 11,
#    'KASUS': 11,
#    'MENINGGAL': 0,
#    'SEMBUH': 0,
#    'tanggal': 1584403200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 21,
#    'AKUMULASI_KASUS': 29,
#    'AKUMULASI_MENINGGAL': 3,
#    'AKUMULASI_SEMBUH': 5,
#    'DIRAWAT_OR_ISOLASI': 3,
#    'KASUS': 5,
#    'MENINGGAL': 1,
#    'SEMBUH': 1,
#    'tanggal': 1584489600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 27,
#    'AKUMULASI_KASUS': 36,
#    'AKUMULASI_MENINGGAL': 4,
#    'AKUMULASI_SEMBUH': 5,
#    'DIRAWAT_OR_ISOLASI': 6,
#    'KASUS': 7,
#    'MENINGGAL': 1,
#    'SEMBUH': 0,
#    'tanggal': 1584576000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 44,
#    'AKUMULASI_KASUS': 56,
#    'AKUMULASI_MENINGGAL': 7,
#    'AKUMULASI_SEMBUH': 5,
#    'DIRAWAT_OR_ISOLASI': 17,
#    'KASUS': 20,
#    'MENINGGAL': 3,
#    'SEMBUH': 0,
#    'tanggal': 1584662400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 49,
#    'AKUMULASI_KASUS': 61,
#    'AKUMULASI_MENINGGAL': 7,
#    'AKUMULASI_SEMBUH': 5,
#    'DIRAWAT_OR_ISOLASI': 5,
#    'KASUS': 5,
#    'MENINGGAL': 0,
#    'SEMBUH': 0,
#    'tanggal': 1584748800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 49,
#    'AKUMULASI_KASUS': 64,
#    'AKUMULASI_MENINGGAL': 10,
#    'AKUMULASI_SEMBUH': 5,
#    'DIRAWAT_OR_ISOLASI': 0,
#    'KASUS': 3,
#    'MENINGGAL': 3,
#    'SEMBUH': 0,
#    'tanggal': 1584835200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 51,
#    'AKUMULASI_KASUS': 70,
#    'AKUMULASI_MENINGGAL': 14,
#    'AKUMULASI_SEMBUH': 5,
#    'DIRAWAT_OR_ISOLASI': 2,
#    'KASUS': 6,
#    'MENINGGAL': 4,
#    'SEMBUH': 0,
#    'tanggal': 1584921600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 50,
#    'AKUMULASI_KASUS': 72,
#    'AKUMULASI_MENINGGAL': 16,
#    'AKUMULASI_SEMBUH': 6,
#    'DIRAWAT_OR_ISOLASI': -1,
#    'KASUS': 2,
#    'MENINGGAL': 2,
#    'SEMBUH': 1,
#    'tanggal': 1585008000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 54,
#    'AKUMULASI_KASUS': 77,
#    'AKUMULASI_MENINGGAL': 16,
#    'AKUMULASI_SEMBUH': 7,
#    'DIRAWAT_OR_ISOLASI': 4,
#    'KASUS': 5,
#    'MENINGGAL': 0,
#    'SEMBUH': 1,
#    'tanggal': 1585094400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 62,
#    'AKUMULASI_KASUS': 85,
#    'AKUMULASI_MENINGGAL': 16,
#    'AKUMULASI_SEMBUH': 7,
#    'DIRAWAT_OR_ISOLASI': 8,
#    'KASUS': 8,
#    'MENINGGAL': 0,
#    'SEMBUH': 0,
#    'tanggal': 1585180800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 85,
#    'AKUMULASI_KASUS': 112,
#    'AKUMULASI_MENINGGAL': 20,
#    'AKUMULASI_SEMBUH': 7,
#    'DIRAWAT_OR_ISOLASI': 23,
#    'KASUS': 27,
#    'MENINGGAL': 4,
#    'SEMBUH': 0,
#    'tanggal': 1585267200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 105,
#    'AKUMULASI_KASUS': 135,
#    'AKUMULASI_MENINGGAL': 22,
#    'AKUMULASI_SEMBUH': 8,
#    'DIRAWAT_OR_ISOLASI': 20,
#    'KASUS': 23,
#    'MENINGGAL': 2,
#    'SEMBUH': 1,
#    'tanggal': 1585353600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 135,
#    'AKUMULASI_KASUS': 168,
#    'AKUMULASI_MENINGGAL': 24,
#    'AKUMULASI_SEMBUH': 9,
#    'DIRAWAT_OR_ISOLASI': 30,
#    'KASUS': 33,
#    'MENINGGAL': 2,
#    'SEMBUH': 1,
#    'tanggal': 1585440000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 156,
#    'AKUMULASI_KASUS': 194,
#    'AKUMULASI_MENINGGAL': 26,
#    'AKUMULASI_SEMBUH': 12,
#    'DIRAWAT_OR_ISOLASI': 21,
#    'KASUS': 26,
#    'MENINGGAL': 2,
#    'SEMBUH': 3,
#    'tanggal': 1585526400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 162,
#    'AKUMULASI_KASUS': 203,
#    'AKUMULASI_MENINGGAL': 26,
#    'AKUMULASI_SEMBUH': 15,
#    'DIRAWAT_OR_ISOLASI': 6,
#    'KASUS': 9,
#    'MENINGGAL': 0,
#    'SEMBUH': 3,
#    'tanggal': 1585612800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 188,
#    'AKUMULASI_KASUS': 230,
#    'AKUMULASI_MENINGGAL': 27,
#    'AKUMULASI_SEMBUH': 15,
#    'DIRAWAT_OR_ISOLASI': 26,
#    'KASUS': 27,
#    'MENINGGAL': 1,
#    'SEMBUH': 0,
#    'tanggal': 1585699200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 207,
#    'AKUMULASI_KASUS': 254,
#    'AKUMULASI_MENINGGAL': 31,
#    'AKUMULASI_SEMBUH': 16,
#    'DIRAWAT_OR_ISOLASI': 19,
#    'KASUS': 24,
#    'MENINGGAL': 4,
#    'SEMBUH': 1,
#    'tanggal': 1585785600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 205,
#    'AKUMULASI_KASUS': 256,
#    'AKUMULASI_MENINGGAL': 32,
#    'AKUMULASI_SEMBUH': 19,
#    'DIRAWAT_OR_ISOLASI': -2,
#    'KASUS': 2,
#    'MENINGGAL': 1,
#    'SEMBUH': 3,
#    'tanggal': 1585872000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 227,
#    'AKUMULASI_KASUS': 280,
#    'AKUMULASI_MENINGGAL': 34,
#    'AKUMULASI_SEMBUH': 19,
#    'DIRAWAT_OR_ISOLASI': 22,
#    'KASUS': 24,
#    'MENINGGAL': 2,
#    'SEMBUH': 0,
#    'tanggal': 1585958400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 236,
#    'AKUMULASI_KASUS': 290,
#    'AKUMULASI_MENINGGAL': 34,
#    'AKUMULASI_SEMBUH': 20,
#    'DIRAWAT_OR_ISOLASI': 9,
#    'KASUS': 10,
#    'MENINGGAL': 0,
#    'SEMBUH': 1,
#    'tanggal': 1586044800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 253,
#    'AKUMULASI_KASUS': 310,
#    'AKUMULASI_MENINGGAL': 36,
#    'AKUMULASI_SEMBUH': 21,
#    'DIRAWAT_OR_ISOLASI': 17,
#    'KASUS': 20,
#    'MENINGGAL': 2,
#    'SEMBUH': 1,
#    'tanggal': 1586131200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 327,
#    'AKUMULASI_KASUS': 389,
#    'AKUMULASI_MENINGGAL': 38,
#    'AKUMULASI_SEMBUH': 24,
#    'DIRAWAT_OR_ISOLASI': 74,
#    'KASUS': 79,
#    'MENINGGAL': 2,
#    'SEMBUH': 3,
#    'tanggal': 1586217600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 345,
#    'AKUMULASI_KASUS': 413,
#    'AKUMULASI_MENINGGAL': 43,
#    'AKUMULASI_SEMBUH': 25,
#    'DIRAWAT_OR_ISOLASI': 18,
#    'KASUS': 24,
#    'MENINGGAL': 5,
#    'SEMBUH': 1,
#    'tanggal': 1586304000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 361,
#    'AKUMULASI_KASUS': 435,
#    'AKUMULASI_MENINGGAL': 48,
#    'AKUMULASI_SEMBUH': 26,
#    'DIRAWAT_OR_ISOLASI': 16,
#    'KASUS': 22,
#    'MENINGGAL': 5,
#    'SEMBUH': 1,
#    'tanggal': 1586390400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 370,
#    'AKUMULASI_KASUS': 445,
#    'AKUMULASI_MENINGGAL': 48,
#    'AKUMULASI_SEMBUH': 27,
#    'DIRAWAT_OR_ISOLASI': 9,
#    'KASUS': 10,
#    'MENINGGAL': 0,
#    'SEMBUH': 1,
#    'tanggal': 1586476800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 413,
#    'AKUMULASI_KASUS': 490,
#    'AKUMULASI_MENINGGAL': 49,
#    'AKUMULASI_SEMBUH': 28,
#    'DIRAWAT_OR_ISOLASI': 43,
#    'KASUS': 45,
#    'MENINGGAL': 1,
#    'SEMBUH': 1,
#    'tanggal': 1586563200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 441,
#    'AKUMULASI_KASUS': 525,
#    'AKUMULASI_MENINGGAL': 53,
#    'AKUMULASI_SEMBUH': 31,
#    'DIRAWAT_OR_ISOLASI': 28,
#    'KASUS': 35,
#    'MENINGGAL': 4,
#    'SEMBUH': 3,
#    'tanggal': 1586649600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 504,
#    'AKUMULASI_KASUS': 601,
#    'AKUMULASI_MENINGGAL': 63,
#    'AKUMULASI_SEMBUH': 34,
#    'DIRAWAT_OR_ISOLASI': 63,
#    'KASUS': 76,
#    'MENINGGAL': 10,
#    'SEMBUH': 3,
#    'tanggal': 1586736000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 508,
#    'AKUMULASI_KASUS': 607,
#    'AKUMULASI_MENINGGAL': 64,
#    'AKUMULASI_SEMBUH': 35,
#    'DIRAWAT_OR_ISOLASI': 4,
#    'KASUS': 6,
#    'MENINGGAL': 1,
#    'SEMBUH': 1,
#    'tanggal': 1586822400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 542,
#    'AKUMULASI_KASUS': 645,
#    'AKUMULASI_MENINGGAL': 67,
#    'AKUMULASI_SEMBUH': 36,
#    'DIRAWAT_OR_ISOLASI': 34,
#    'KASUS': 38,
#    'MENINGGAL': 3,
#    'SEMBUH': 1,
#    'tanggal': 1586908800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 558,
#    'AKUMULASI_KASUS': 668,
#    'AKUMULASI_MENINGGAL': 68,
#    'AKUMULASI_SEMBUH': 42,
#    'DIRAWAT_OR_ISOLASI': 16,
#    'KASUS': 23,
#    'MENINGGAL': 1,
#    'SEMBUH': 6,
#    'tanggal': 1586995200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 600,
#    'AKUMULASI_KASUS': 729,
#    'AKUMULASI_MENINGGAL': 71,
#    'AKUMULASI_SEMBUH': 58,
#    'DIRAWAT_OR_ISOLASI': 42,
#    'KASUS': 61,
#    'MENINGGAL': 3,
#    'SEMBUH': 16,
#    'tanggal': 1587081600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 617,
#    'AKUMULASI_KASUS': 748,
#    'AKUMULASI_MENINGGAL': 71,
#    'AKUMULASI_SEMBUH': 60,
#    'DIRAWAT_OR_ISOLASI': 17,
#    'KASUS': 19,
#    'MENINGGAL': 0,
#    'SEMBUH': 2,
#    'tanggal': 1587168000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 658,
#    'AKUMULASI_KASUS': 802,
#    'AKUMULASI_MENINGGAL': 72,
#    'AKUMULASI_SEMBUH': 72,
#    'DIRAWAT_OR_ISOLASI': 41,
#    'KASUS': 54,
#    'MENINGGAL': 1,
#    'SEMBUH': 12,
#    'tanggal': 1587254400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 678,
#    'AKUMULASI_KASUS': 829,
#    'AKUMULASI_MENINGGAL': 75,
#    'AKUMULASI_SEMBUH': 76,
#    'DIRAWAT_OR_ISOLASI': 20,
#    'KASUS': 27,
#    'MENINGGAL': 3,
#    'SEMBUH': 4,
#    'tanggal': 1587340800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 673,
#    'AKUMULASI_KASUS': 848,
#    'AKUMULASI_MENINGGAL': 80,
#    'AKUMULASI_SEMBUH': 95,
#    'DIRAWAT_OR_ISOLASI': -5,
#    'KASUS': 19,
#    'MENINGGAL': 5,
#    'SEMBUH': 19,
#    'tanggal': 1587427200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 675,
#    'AKUMULASI_KASUS': 856,
#    'AKUMULASI_MENINGGAL': 83,
#    'AKUMULASI_SEMBUH': 98,
#    'DIRAWAT_OR_ISOLASI': 2,
#    'KASUS': 8,
#    'MENINGGAL': 3,
#    'SEMBUH': 3,
#    'tanggal': 1587513600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 692,
#    'AKUMULASI_KASUS': 885,
#    'AKUMULASI_MENINGGAL': 86,
#    'AKUMULASI_SEMBUH': 107,
#    'DIRAWAT_OR_ISOLASI': 17,
#    'KASUS': 29,
#    'MENINGGAL': 3,
#    'SEMBUH': 9,
#    'tanggal': 1587600000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 761,
#    'AKUMULASI_KASUS': 959,
#    'AKUMULASI_MENINGGAL': 88,
#    'AKUMULASI_SEMBUH': 110,
#    'DIRAWAT_OR_ISOLASI': 69,
#    'KASUS': 74,
#    'MENINGGAL': 2,
#    'SEMBUH': 3,
#    'tanggal': 1587686400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 804,
#    'AKUMULASI_KASUS': 1006,
#    'AKUMULASI_MENINGGAL': 88,
#    'AKUMULASI_SEMBUH': 114,
#    'DIRAWAT_OR_ISOLASI': 43,
#    'KASUS': 47,
#    'MENINGGAL': 0,
#    'SEMBUH': 4,
#    'tanggal': 1587772800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 815,
#    'AKUMULASI_KASUS': 1018,
#    'AKUMULASI_MENINGGAL': 88,
#    'AKUMULASI_SEMBUH': 115,
#    'DIRAWAT_OR_ISOLASI': 11,
#    'KASUS': 12,
#    'MENINGGAL': 0,
#    'SEMBUH': 1,
#    'tanggal': 1587859200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 849,
#    'AKUMULASI_KASUS': 1056,
#    'AKUMULASI_MENINGGAL': 89,
#    'AKUMULASI_SEMBUH': 118,
#    'DIRAWAT_OR_ISOLASI': 34,
#    'KASUS': 38,
#    'MENINGGAL': 1,
#    'SEMBUH': 3,
#    'tanggal': 1587945600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 861,
#    'AKUMULASI_KASUS': 1075,
#    'AKUMULASI_MENINGGAL': 90,
#    'AKUMULASI_SEMBUH': 124,
#    'DIRAWAT_OR_ISOLASI': 12,
#    'KASUS': 19,
#    'MENINGGAL': 1,
#    'SEMBUH': 6,
#    'tanggal': 1588032000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 894,
#    'AKUMULASI_KASUS': 1115,
#    'AKUMULASI_MENINGGAL': 90,
#    'AKUMULASI_SEMBUH': 131,
#    'DIRAWAT_OR_ISOLASI': 33,
#    'KASUS': 40,
#    'MENINGGAL': 0,
#    'SEMBUH': 7,
#    'tanggal': 1588118400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 864,
#    'AKUMULASI_KASUS': 1120,
#    'AKUMULASI_MENINGGAL': 94,
#    'AKUMULASI_SEMBUH': 162,
#    'DIRAWAT_OR_ISOLASI': -30,
#    'KASUS': 5,
#    'MENINGGAL': 4,
#    'SEMBUH': 31,
#    'tanggal': 1588204800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 865,
#    'AKUMULASI_KASUS': 1124,
#    'AKUMULASI_MENINGGAL': 94,
#    'AKUMULASI_SEMBUH': 165,
#    'DIRAWAT_OR_ISOLASI': 1,
#    'KASUS': 4,
#    'MENINGGAL': 0,
#    'SEMBUH': 3,
#    'tanggal': 1588291200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 898,
#    'AKUMULASI_KASUS': 1160,
#    'AKUMULASI_MENINGGAL': 95,
#    'AKUMULASI_SEMBUH': 167,
#    'DIRAWAT_OR_ISOLASI': 33,
#    'KASUS': 36,
#    'MENINGGAL': 1,
#    'SEMBUH': 2,
#    'tanggal': 1588377600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 904,
#    'AKUMULASI_KASUS': 1174,
#    'AKUMULASI_MENINGGAL': 96,
#    'AKUMULASI_SEMBUH': 174,
#    'DIRAWAT_OR_ISOLASI': 6,
#    'KASUS': 14,
#    'MENINGGAL': 1,
#    'SEMBUH': 7,
#    'tanggal': 1588464000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1076,
#    'AKUMULASI_KASUS': 1356,
#    'AKUMULASI_MENINGGAL': 99,
#    'AKUMULASI_SEMBUH': 181,
#    'DIRAWAT_OR_ISOLASI': 172,
#    'KASUS': 182,
#    'MENINGGAL': 3,
#    'SEMBUH': 7,
#    'tanggal': 1588550400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1117,
#    'AKUMULASI_KASUS': 1408,
#    'AKUMULASI_MENINGGAL': 100,
#    'AKUMULASI_SEMBUH': 191,
#    'DIRAWAT_OR_ISOLASI': 41,
#    'KASUS': 52,
#    'MENINGGAL': 1,
#    'SEMBUH': 10,
#    'tanggal': 1588636800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1127,
#    'AKUMULASI_KASUS': 1429,
#    'AKUMULASI_MENINGGAL': 103,
#    'AKUMULASI_SEMBUH': 199,
#    'DIRAWAT_OR_ISOLASI': 10,
#    'KASUS': 21,
#    'MENINGGAL': 3,
#    'SEMBUH': 8,
#    'tanggal': 1588723200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1174,
#    'AKUMULASI_KASUS': 1482,
#    'AKUMULASI_MENINGGAL': 103,
#    'AKUMULASI_SEMBUH': 205,
#    'DIRAWAT_OR_ISOLASI': 47,
#    'KASUS': 53,
#    'MENINGGAL': 0,
#    'SEMBUH': 6,
#    'tanggal': 1588809600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1202,
#    'AKUMULASI_KASUS': 1512,
#    'AKUMULASI_MENINGGAL': 105,
#    'AKUMULASI_SEMBUH': 205,
#    'DIRAWAT_OR_ISOLASI': 28,
#    'KASUS': 30,
#    'MENINGGAL': 2,
#    'SEMBUH': 0,
#    'tanggal': 1588896000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1209,
#    'AKUMULASI_KASUS': 1541,
#    'AKUMULASI_MENINGGAL': 108,
#    'AKUMULASI_SEMBUH': 224,
#    'DIRAWAT_OR_ISOLASI': 7,
#    'KASUS': 29,
#    'MENINGGAL': 3,
#    'SEMBUH': 19,
#    'tanggal': 1588982400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1207,
#    'AKUMULASI_KASUS': 1541,
#    'AKUMULASI_MENINGGAL': 108,
#    'AKUMULASI_SEMBUH': 226,
#    'DIRAWAT_OR_ISOLASI': -2,
#    'KASUS': 0,
#    'MENINGGAL': 0,
#    'SEMBUH': 2,
#    'tanggal': 1589068800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1247,
#    'AKUMULASI_KASUS': 1595,
#    'AKUMULASI_MENINGGAL': 111,
#    'AKUMULASI_SEMBUH': 237,
#    'DIRAWAT_OR_ISOLASI': 40,
#    'KASUS': 54,
#    'MENINGGAL': 3,
#    'SEMBUH': 11,
#    'tanggal': 1589155200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1297,
#    'AKUMULASI_KASUS': 1649,
#    'AKUMULASI_MENINGGAL': 111,
#    'AKUMULASI_SEMBUH': 241,
#    'DIRAWAT_OR_ISOLASI': 50,
#    'KASUS': 54,
#    'MENINGGAL': 0,
#    'SEMBUH': 4,
#    'tanggal': 1589241600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1278,
#    'AKUMULASI_KASUS': 1657,
#    'AKUMULASI_MENINGGAL': 111,
#    'AKUMULASI_SEMBUH': 268,
#    'DIRAWAT_OR_ISOLASI': -19,
#    'KASUS': 8,
#    'MENINGGAL': 0,
#    'SEMBUH': 27,
#    'tanggal': 1589328000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1281,
#    'AKUMULASI_KASUS': 1668,
#    'AKUMULASI_MENINGGAL': 112,
#    'AKUMULASI_SEMBUH': 275,
#    'DIRAWAT_OR_ISOLASI': 3,
#    'KASUS': 11,
#    'MENINGGAL': 1,
#    'SEMBUH': 7,
#    'tanggal': 1589414400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1295,
#    'AKUMULASI_KASUS': 1701,
#    'AKUMULASI_MENINGGAL': 113,
#    'AKUMULASI_SEMBUH': 293,
#    'DIRAWAT_OR_ISOLASI': 14,
#    'KASUS': 33,
#    'MENINGGAL': 1,
#    'SEMBUH': 18,
#    'tanggal': 1589500800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1316,
#    'AKUMULASI_KASUS': 1725,
#    'AKUMULASI_MENINGGAL': 113,
#    'AKUMULASI_SEMBUH': 296,
#    'DIRAWAT_OR_ISOLASI': 21,
#    'KASUS': 24,
#    'MENINGGAL': 0,
#    'SEMBUH': 3,
#    'tanggal': 1589587200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1288,
#    'AKUMULASI_KASUS': 1757,
#    'AKUMULASI_MENINGGAL': 116,
#    'AKUMULASI_SEMBUH': 353,
#    'DIRAWAT_OR_ISOLASI': -28,
#    'KASUS': 32,
#    'MENINGGAL': 3,
#    'SEMBUH': 57,
#    'tanggal': 1589673600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1227,
#    'AKUMULASI_KASUS': 1779,
#    'AKUMULASI_MENINGGAL': 125,
#    'AKUMULASI_SEMBUH': 427,
#    'DIRAWAT_OR_ISOLASI': -61,
#    'KASUS': 22,
#    'MENINGGAL': 9,
#    'SEMBUH': 74,
#    'tanggal': 1589760000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1236,
#    'AKUMULASI_KASUS': 1803,
#    'AKUMULASI_MENINGGAL': 126,
#    'AKUMULASI_SEMBUH': 441,
#    'DIRAWAT_OR_ISOLASI': 9,
#    'KASUS': 24,
#    'MENINGGAL': 1,
#    'SEMBUH': 14,
#    'tanggal': 1589846400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1377,
#    'AKUMULASI_KASUS': 1946,
#    'AKUMULASI_MENINGGAL': 126,
#    'AKUMULASI_SEMBUH': 443,
#    'DIRAWAT_OR_ISOLASI': 141,
#    'KASUS': 143,
#    'MENINGGAL': 0,
#    'SEMBUH': 2,
#    'tanggal': 1589932800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1434,
#    'AKUMULASI_KASUS': 2014,
#    'AKUMULASI_MENINGGAL': 126,
#    'AKUMULASI_SEMBUH': 454,
#    'DIRAWAT_OR_ISOLASI': 57,
#    'KASUS': 68,
#    'MENINGGAL': 0,
#    'SEMBUH': 11,
#    'tanggal': 1590019200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1457,
#    'AKUMULASI_KASUS': 2052,
#    'AKUMULASI_MENINGGAL': 128,
#    'AKUMULASI_SEMBUH': 467,
#    'DIRAWAT_OR_ISOLASI': 23,
#    'KASUS': 38,
#    'MENINGGAL': 2,
#    'SEMBUH': 13,
#    'tanggal': 1590105600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1470,
#    'AKUMULASI_KASUS': 2107,
#    'AKUMULASI_MENINGGAL': 130,
#    'AKUMULASI_SEMBUH': 507,
#    'DIRAWAT_OR_ISOLASI': 13,
#    'KASUS': 55,
#    'MENINGGAL': 2,
#    'SEMBUH': 40,
#    'tanggal': 1590192000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1507,
#    'AKUMULASI_KASUS': 2156,
#    'AKUMULASI_MENINGGAL': 131,
#    'AKUMULASI_SEMBUH': 518,
#    'DIRAWAT_OR_ISOLASI': 37,
#    'KASUS': 49,
#    'MENINGGAL': 1,
#    'SEMBUH': 11,
#    'tanggal': 1590278400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1521,
#    'AKUMULASI_KASUS': 2174,
#    'AKUMULASI_MENINGGAL': 131,
#    'AKUMULASI_SEMBUH': 522,
#    'DIRAWAT_OR_ISOLASI': 14,
#    'KASUS': 18,
#    'MENINGGAL': 0,
#    'SEMBUH': 4,
#    'tanggal': 1590364800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1506,
#    'AKUMULASI_KASUS': 2189,
#    'AKUMULASI_MENINGGAL': 140,
#    'AKUMULASI_SEMBUH': 543,
#    'DIRAWAT_OR_ISOLASI': -15,
#    'KASUS': 15,
#    'MENINGGAL': 9,
#    'SEMBUH': 21,
#    'tanggal': 1590451200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1494,
#    'AKUMULASI_KASUS': 2214,
#    'AKUMULASI_MENINGGAL': 145,
#    'AKUMULASI_SEMBUH': 575,
#    'DIRAWAT_OR_ISOLASI': -12,
#    'KASUS': 25,
#    'MENINGGAL': 5,
#    'SEMBUH': 32,
#    'tanggal': 1590537600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1475,
#    'AKUMULASI_KASUS': 2240,
#    'AKUMULASI_MENINGGAL': 145,
#    'AKUMULASI_SEMBUH': 620,
#    'DIRAWAT_OR_ISOLASI': -19,
#    'KASUS': 26,
#    'MENINGGAL': 0,
#    'SEMBUH': 45,
#    'tanggal': 1590624000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1508,
#    'AKUMULASI_KASUS': 2280,
#    'AKUMULASI_MENINGGAL': 146,
#    'AKUMULASI_SEMBUH': 626,
#    'DIRAWAT_OR_ISOLASI': 33,
#    'KASUS': 40,
#    'MENINGGAL': 1,
#    'SEMBUH': 6,
#    'tanggal': 1590710400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1494,
#    'AKUMULASI_KASUS': 2300,
#    'AKUMULASI_MENINGGAL': 148,
#    'AKUMULASI_SEMBUH': 658,
#    'DIRAWAT_OR_ISOLASI': -14,
#    'KASUS': 20,
#    'MENINGGAL': 2,
#    'SEMBUH': 32,
#    'tanggal': 1590796800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1524,
#    'AKUMULASI_KASUS': 2338,
#    'AKUMULASI_MENINGGAL': 148,
#    'AKUMULASI_SEMBUH': 666,
#    'DIRAWAT_OR_ISOLASI': 30,
#    'KASUS': 38,
#    'MENINGGAL': 0,
#    'SEMBUH': 8,
#    'tanggal': 1590883200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1557,
#    'AKUMULASI_KASUS': 2379,
#    'AKUMULASI_MENINGGAL': 148,
#    'AKUMULASI_SEMBUH': 674,
#    'DIRAWAT_OR_ISOLASI': 33,
#    'KASUS': 41,
#    'MENINGGAL': 0,
#    'SEMBUH': 8,
#    'tanggal': 1590969600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1532,
#    'AKUMULASI_KASUS': 2397,
#    'AKUMULASI_MENINGGAL': 155,
#    'AKUMULASI_SEMBUH': 710,
#    'DIRAWAT_OR_ISOLASI': -25,
#    'KASUS': 18,
#    'MENINGGAL': 7,
#    'SEMBUH': 36,
#    'tanggal': 1591056000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1478,
#    'AKUMULASI_KASUS': 2401,
#    'AKUMULASI_MENINGGAL': 158,
#    'AKUMULASI_SEMBUH': 765,
#    'DIRAWAT_OR_ISOLASI': -54,
#    'KASUS': 4,
#    'MENINGGAL': 3,
#    'SEMBUH': 55,
#    'tanggal': 1591142400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1464,
#    'AKUMULASI_KASUS': 2409,
#    'AKUMULASI_MENINGGAL': 159,
#    'AKUMULASI_SEMBUH': 786,
#    'DIRAWAT_OR_ISOLASI': -14,
#    'KASUS': 8,
#    'MENINGGAL': 1,
#    'SEMBUH': 21,
#    'tanggal': 1591228800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1429,
#    'AKUMULASI_KASUS': 2424,
#    'AKUMULASI_MENINGGAL': 162,
#    'AKUMULASI_SEMBUH': 833,
#    'DIRAWAT_OR_ISOLASI': -35,
#    'KASUS': 15,
#    'MENINGGAL': 3,
#    'SEMBUH': 47,
#    'tanggal': 1591315200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1426,
#    'AKUMULASI_KASUS': 2437,
#    'AKUMULASI_MENINGGAL': 162,
#    'AKUMULASI_SEMBUH': 849,
#    'DIRAWAT_OR_ISOLASI': -3,
#    'KASUS': 13,
#    'MENINGGAL': 0,
#    'SEMBUH': 16,
#    'tanggal': 1591401600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1354,
#    'AKUMULASI_KASUS': 2471,
#    'AKUMULASI_MENINGGAL': 162,
#    'AKUMULASI_SEMBUH': 955,
#    'DIRAWAT_OR_ISOLASI': -72,
#    'KASUS': 34,
#    'MENINGGAL': 0,
#    'SEMBUH': 106,
#    'tanggal': 1591488000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1307,
#    'AKUMULASI_KASUS': 2495,
#    'AKUMULASI_MENINGGAL': 165,
#    'AKUMULASI_SEMBUH': 1023,
#    'DIRAWAT_OR_ISOLASI': -47,
#    'KASUS': 24,
#    'MENINGGAL': 3,
#    'SEMBUH': 68,
#    'tanggal': 1591574400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1324,
#    'AKUMULASI_KASUS': 2524,
#    'AKUMULASI_MENINGGAL': 165,
#    'AKUMULASI_SEMBUH': 1035,
#    'DIRAWAT_OR_ISOLASI': 17,
#    'KASUS': 29,
#    'MENINGGAL': 0,
#    'SEMBUH': 12,
#    'tanggal': 1591660800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1335,
#    'AKUMULASI_KASUS': 2573,
#    'AKUMULASI_MENINGGAL': 165,
#    'AKUMULASI_SEMBUH': 1073,
#    'DIRAWAT_OR_ISOLASI': 11,
#    'KASUS': 49,
#    'MENINGGAL': 0,
#    'SEMBUH': 38,
#    'tanggal': 1591747200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1362,
#    'AKUMULASI_KASUS': 2620,
#    'AKUMULASI_MENINGGAL': 165,
#    'AKUMULASI_SEMBUH': 1093,
#    'DIRAWAT_OR_ISOLASI': 27,
#    'KASUS': 47,
#    'MENINGGAL': 0,
#    'SEMBUH': 20,
#    'tanggal': 1591833600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1330,
#    'AKUMULASI_KASUS': 2635,
#    'AKUMULASI_MENINGGAL': 165,
#    'AKUMULASI_SEMBUH': 1140,
#    'DIRAWAT_OR_ISOLASI': -32,
#    'KASUS': 15,
#    'MENINGGAL': 0,
#    'SEMBUH': 47,
#    'tanggal': 1591920000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1306,
#    'AKUMULASI_KASUS': 2647,
#    'AKUMULASI_MENINGGAL': 165,
#    'AKUMULASI_SEMBUH': 1176,
#    'DIRAWAT_OR_ISOLASI': -24,
#    'KASUS': 12,
#    'MENINGGAL': 0,
#    'SEMBUH': 36,
#    'tanggal': 1592006400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1282,
#    'AKUMULASI_KASUS': 2662,
#    'AKUMULASI_MENINGGAL': 165,
#    'AKUMULASI_SEMBUH': 1215,
#    'DIRAWAT_OR_ISOLASI': -24,
#    'KASUS': 15,
#    'MENINGGAL': 0,
#    'SEMBUH': 39,
#    'tanggal': 1592092800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1298,
#    'AKUMULASI_KASUS': 2686,
#    'AKUMULASI_MENINGGAL': 166,
#    'AKUMULASI_SEMBUH': 1222,
#    'DIRAWAT_OR_ISOLASI': 16,
#    'KASUS': 24,
#    'MENINGGAL': 1,
#    'SEMBUH': 7,
#    'tanggal': 1592179200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1323,
#    'AKUMULASI_KASUS': 2723,
#    'AKUMULASI_MENINGGAL': 166,
#    'AKUMULASI_SEMBUH': 1234,
#    'DIRAWAT_OR_ISOLASI': 25,
#    'KASUS': 37,
#    'MENINGGAL': 0,
#    'SEMBUH': 12,
#    'tanggal': 1592265600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1331,
#    'AKUMULASI_KASUS': 2766,
#    'AKUMULASI_MENINGGAL': 173,
#    'AKUMULASI_SEMBUH': 1262,
#    'DIRAWAT_OR_ISOLASI': 8,
#    'KASUS': 43,
#    'MENINGGAL': 7,
#    'SEMBUH': 28,
#    'tanggal': 1592352000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1326,
#    'AKUMULASI_KASUS': 2817,
#    'AKUMULASI_MENINGGAL': 175,
#    'AKUMULASI_SEMBUH': 1316,
#    'DIRAWAT_OR_ISOLASI': -5,
#    'KASUS': 51,
#    'MENINGGAL': 2,
#    'SEMBUH': 54,
#    'tanggal': 1592438400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1360,
#    'AKUMULASI_KASUS': 2880,
#    'AKUMULASI_MENINGGAL': 175,
#    'AKUMULASI_SEMBUH': 1345,
#    'DIRAWAT_OR_ISOLASI': 34,
#    'KASUS': 63,
#    'MENINGGAL': 0,
#    'SEMBUH': 29,
#    'tanggal': 1592524800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1378,
#    'AKUMULASI_KASUS': 2899,
#    'AKUMULASI_MENINGGAL': 175,
#    'AKUMULASI_SEMBUH': 1346,
#    'DIRAWAT_OR_ISOLASI': 18,
#    'KASUS': 19,
#    'MENINGGAL': 0,
#    'SEMBUH': 1,
#    'tanggal': 1592611200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1398,
#    'AKUMULASI_KASUS': 2921,
#    'AKUMULASI_MENINGGAL': 175,
#    'AKUMULASI_SEMBUH': 1348,
#    'DIRAWAT_OR_ISOLASI': 20,
#    'KASUS': 22,
#    'MENINGGAL': 0,
#    'SEMBUH': 2,
#    'tanggal': 1592697600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1392,
#    'AKUMULASI_KASUS': 2939,
#    'AKUMULASI_MENINGGAL': 175,
#    'AKUMULASI_SEMBUH': 1372,
#    'DIRAWAT_OR_ISOLASI': -6,
#    'KASUS': 18,
#    'MENINGGAL': 0,
#    'SEMBUH': 24,
#    'tanggal': 1592784000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1394,
#    'AKUMULASI_KASUS': 2971,
#    'AKUMULASI_MENINGGAL': 175,
#    'AKUMULASI_SEMBUH': 1402,
#    'DIRAWAT_OR_ISOLASI': 2,
#    'KASUS': 32,
#    'MENINGGAL': 0,
#    'SEMBUH': 30,
#    'tanggal': 1592870400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1432,
#    'AKUMULASI_KASUS': 3017,
#    'AKUMULASI_MENINGGAL': 175,
#    'AKUMULASI_SEMBUH': 1410,
#    'DIRAWAT_OR_ISOLASI': 38,
#    'KASUS': 46,
#    'MENINGGAL': 0,
#    'SEMBUH': 8,
#    'tanggal': 1592956800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1414,
#    'AKUMULASI_KASUS': 3058,
#    'AKUMULASI_MENINGGAL': 177,
#    'AKUMULASI_SEMBUH': 1467,
#    'DIRAWAT_OR_ISOLASI': -18,
#    'KASUS': 41,
#    'MENINGGAL': 2,
#    'SEMBUH': 57,
#    'tanggal': 1593043200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1338,
#    'AKUMULASI_KASUS': 3093,
#    'AKUMULASI_MENINGGAL': 179,
#    'AKUMULASI_SEMBUH': 1576,
#    'DIRAWAT_OR_ISOLASI': -76,
#    'KASUS': 35,
#    'MENINGGAL': 2,
#    'SEMBUH': 109,
#    'tanggal': 1593129600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1373,
#    'AKUMULASI_KASUS': 3142,
#    'AKUMULASI_MENINGGAL': 179,
#    'AKUMULASI_SEMBUH': 1590,
#    'DIRAWAT_OR_ISOLASI': 35,
#    'KASUS': 49,
#    'MENINGGAL': 0,
#    'SEMBUH': 14,
#    'tanggal': 1593216000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1390,
#    'AKUMULASI_KASUS': 3168,
#    'AKUMULASI_MENINGGAL': 179,
#    'AKUMULASI_SEMBUH': 1599,
#    'DIRAWAT_OR_ISOLASI': 17,
#    'KASUS': 26,
#    'MENINGGAL': 0,
#    'SEMBUH': 9,
#    'tanggal': 1593302400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1429,
#    'AKUMULASI_KASUS': 3210,
#    'AKUMULASI_MENINGGAL': 179,
#    'AKUMULASI_SEMBUH': 1602,
#    'DIRAWAT_OR_ISOLASI': 39,
#    'KASUS': 42,
#    'MENINGGAL': 0,
#    'SEMBUH': 3,
#    'tanggal': 1593388800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1419,
#    'AKUMULASI_KASUS': 3285,
#    'AKUMULASI_MENINGGAL': 180,
#    'AKUMULASI_SEMBUH': 1686,
#    'DIRAWAT_OR_ISOLASI': -10,
#    'KASUS': 75,
#    'MENINGGAL': 1,
#    'SEMBUH': 84,
#    'tanggal': 1593475200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1462,
#    'AKUMULASI_KASUS': 3343,
#    'AKUMULASI_MENINGGAL': 180,
#    'AKUMULASI_SEMBUH': 1701,
#    'DIRAWAT_OR_ISOLASI': 43,
#    'KASUS': 58,
#    'MENINGGAL': 0,
#    'SEMBUH': 15,
#    'tanggal': 1593561600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1482,
#    'AKUMULASI_KASUS': 3408,
#    'AKUMULASI_MENINGGAL': 180,
#    'AKUMULASI_SEMBUH': 1746,
#    'DIRAWAT_OR_ISOLASI': 20,
#    'KASUS': 65,
#    'MENINGGAL': 0,
#    'SEMBUH': 45,
#    'tanggal': 1593648000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1510,
#    'AKUMULASI_KASUS': 3440,
#    'AKUMULASI_MENINGGAL': 180,
#    'AKUMULASI_SEMBUH': 1750,
#    'DIRAWAT_OR_ISOLASI': 28,
#    'KASUS': 32,
#    'MENINGGAL': 0,
#    'SEMBUH': 4,
#    'tanggal': 1593734400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1573,
#    'AKUMULASI_KASUS': 3526,
#    'AKUMULASI_MENINGGAL': 180,
#    'AKUMULASI_SEMBUH': 1773,
#    'DIRAWAT_OR_ISOLASI': 63,
#    'KASUS': 86,
#    'MENINGGAL': 0,
#    'SEMBUH': 23,
#    'tanggal': 1593820800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1665,
#    'AKUMULASI_KASUS': 3634,
#    'AKUMULASI_MENINGGAL': 180,
#    'AKUMULASI_SEMBUH': 1789,
#    'DIRAWAT_OR_ISOLASI': 92,
#    'KASUS': 108,
#    'MENINGGAL': 0,
#    'SEMBUH': 16,
#    'tanggal': 1593907200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1771,
#    'AKUMULASI_KASUS': 3763,
#    'AKUMULASI_MENINGGAL': 181,
#    'AKUMULASI_SEMBUH': 1811,
#    'DIRAWAT_OR_ISOLASI': 106,
#    'KASUS': 129,
#    'MENINGGAL': 1,
#    'SEMBUH': 22,
#    'tanggal': 1593993600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1806,
#    'AKUMULASI_KASUS': 3844,
#    'AKUMULASI_MENINGGAL': 183,
#    'AKUMULASI_SEMBUH': 1855,
#    'DIRAWAT_OR_ISOLASI': 35,
#    'KASUS': 81,
#    'MENINGGAL': 2,
#    'SEMBUH': 44,
#    'tanggal': 1594080000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 1874,
#    'AKUMULASI_KASUS': 3939,
#    'AKUMULASI_MENINGGAL': 185,
#    'AKUMULASI_SEMBUH': 1880,
#    'DIRAWAT_OR_ISOLASI': 68,
#    'KASUS': 95,
#    'MENINGGAL': 2,
#    'SEMBUH': 25,
#    'tanggal': 1594166400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 2806,
#    'AKUMULASI_KASUS': 4903,
#    'AKUMULASI_MENINGGAL': 189,
#    'AKUMULASI_SEMBUH': 1908,
#    'DIRAWAT_OR_ISOLASI': 932,
#    'KASUS': 964,
#    'MENINGGAL': 4,
#    'SEMBUH': 28,
#    'tanggal': 1594252800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 2881,
#    'AKUMULASI_KASUS': 5011,
#    'AKUMULASI_MENINGGAL': 189,
#    'AKUMULASI_SEMBUH': 1941,
#    'DIRAWAT_OR_ISOLASI': 75,
#    'KASUS': 108,
#    'MENINGGAL': 0,
#    'SEMBUH': 33,
#    'tanggal': 1594339200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 2924,
#    'AKUMULASI_KASUS': 5084,
#    'AKUMULASI_MENINGGAL': 190,
#    'AKUMULASI_SEMBUH': 1970,
#    'DIRAWAT_OR_ISOLASI': 43,
#    'KASUS': 73,
#    'MENINGGAL': 1,
#    'SEMBUH': 29,
#    'tanggal': 1594425600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 2959,
#    'AKUMULASI_KASUS': 5128,
#    'AKUMULASI_MENINGGAL': 190,
#    'AKUMULASI_SEMBUH': 1979,
#    'DIRAWAT_OR_ISOLASI': 35,
#    'KASUS': 44,
#    'MENINGGAL': 0,
#    'SEMBUH': 9,
#    'tanggal': 1594512000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 3027,
#    'AKUMULASI_KASUS': 5215,
#    'AKUMULASI_MENINGGAL': 190,
#    'AKUMULASI_SEMBUH': 1998,
#    'DIRAWAT_OR_ISOLASI': 68,
#    'KASUS': 87,
#    'MENINGGAL': 0,
#    'SEMBUH': 19,
#    'tanggal': 1594598400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 3069,
#    'AKUMULASI_KASUS': 5292,
#    'AKUMULASI_MENINGGAL': 191,
#    'AKUMULASI_SEMBUH': 2032,
#    'DIRAWAT_OR_ISOLASI': 42,
#    'KASUS': 77,
#    'MENINGGAL': 1,
#    'SEMBUH': 34,
#    'tanggal': 1594684800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 2997,
#    'AKUMULASI_KASUS': 5366,
#    'AKUMULASI_MENINGGAL': 192,
#    'AKUMULASI_SEMBUH': 2177,
#    'DIRAWAT_OR_ISOLASI': -72,
#    'KASUS': 74,
#    'MENINGGAL': 1,
#    'SEMBUH': 145,
#    'tanggal': 1594771200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 3019,
#    'AKUMULASI_KASUS': 5406,
#    'AKUMULASI_MENINGGAL': 192,
#    'AKUMULASI_SEMBUH': 2195,
#    'DIRAWAT_OR_ISOLASI': 22,
#    'KASUS': 40,
#    'MENINGGAL': 0,
#    'SEMBUH': 18,
#    'tanggal': 1594857600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 3036,
#    'AKUMULASI_KASUS': 5457,
#    'AKUMULASI_MENINGGAL': 193,
#    'AKUMULASI_SEMBUH': 2228,
#    'DIRAWAT_OR_ISOLASI': 17,
#    'KASUS': 51,
#    'MENINGGAL': 1,
#    'SEMBUH': 33,
#    'tanggal': 1594944000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 3075,
#    'AKUMULASI_KASUS': 5515,
#    'AKUMULASI_MENINGGAL': 194,
#    'AKUMULASI_SEMBUH': 2246,
#    'DIRAWAT_OR_ISOLASI': 39,
#    'KASUS': 58,
#    'MENINGGAL': 1,
#    'SEMBUH': 18,
#    'tanggal': 1595030400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 3095,
#    'AKUMULASI_KASUS': 5539,
#    'AKUMULASI_MENINGGAL': 194,
#    'AKUMULASI_SEMBUH': 2250,
#    'DIRAWAT_OR_ISOLASI': 20,
#    'KASUS': 24,
#    'MENINGGAL': 0,
#    'SEMBUH': 4,
#    'tanggal': 1595116800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 3058,
#    'AKUMULASI_KASUS': 5598,
#    'AKUMULASI_MENINGGAL': 194,
#    'AKUMULASI_SEMBUH': 2346,
#    'DIRAWAT_OR_ISOLASI': -37,
#    'KASUS': 59,
#    'MENINGGAL': 0,
#    'SEMBUH': 96,
#    'tanggal': 1595203200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 3087,
#    'AKUMULASI_KASUS': 5663,
#    'AKUMULASI_MENINGGAL': 198,
#    'AKUMULASI_SEMBUH': 2378,
#    'DIRAWAT_OR_ISOLASI': 29,
#    'KASUS': 65,
#    'MENINGGAL': 4,
#    'SEMBUH': 32,
#    'tanggal': 1595289600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 3096,
#    'AKUMULASI_KASUS': 5695,
#    'AKUMULASI_MENINGGAL': 198,
#    'AKUMULASI_SEMBUH': 2401,
#    'DIRAWAT_OR_ISOLASI': 9,
#    'KASUS': 32,
#    'MENINGGAL': 0,
#    'SEMBUH': 23,
#    'tanggal': 1595376000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 3145,
#    'AKUMULASI_KASUS': 5758,
#    'AKUMULASI_MENINGGAL': 199,
#    'AKUMULASI_SEMBUH': 2414,
#    'DIRAWAT_OR_ISOLASI': 49,
#    'KASUS': 63,
#    'MENINGGAL': 1,
#    'SEMBUH': 13,
#    'tanggal': 1595462400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 3215,
#    'AKUMULASI_KASUS': 5847,
#    'AKUMULASI_MENINGGAL': 199,
#    'AKUMULASI_SEMBUH': 2433,
#    'DIRAWAT_OR_ISOLASI': 70,
#    'KASUS': 89,
#    'MENINGGAL': 0,
#    'SEMBUH': 19,
#    'tanggal': 1595548800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 3255,
#    'AKUMULASI_KASUS': 5919,
#    'AKUMULASI_MENINGGAL': 199,
#    'AKUMULASI_SEMBUH': 2465,
#    'DIRAWAT_OR_ISOLASI': 40,
#    'KASUS': 72,
#    'MENINGGAL': 0,
#    'SEMBUH': 32,
#    'tanggal': 1595635200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 3282,
#    'AKUMULASI_KASUS': 5969,
#    'AKUMULASI_MENINGGAL': 199,
#    'AKUMULASI_SEMBUH': 2488,
#    'DIRAWAT_OR_ISOLASI': 27,
#    'KASUS': 50,
#    'MENINGGAL': 0,
#    'SEMBUH': 23,
#    'tanggal': 1595721600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 2933,
#    'AKUMULASI_KASUS': 6026,
#    'AKUMULASI_MENINGGAL': 199,
#    'AKUMULASI_SEMBUH': 2894,
#    'DIRAWAT_OR_ISOLASI': -349,
#    'KASUS': 57,
#    'MENINGGAL': 0,
#    'SEMBUH': 406,
#    'tanggal': 1595808000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 2459,
#    'AKUMULASI_KASUS': 6158,
#    'AKUMULASI_MENINGGAL': 199,
#    'AKUMULASI_SEMBUH': 3500,
#    'DIRAWAT_OR_ISOLASI': -474,
#    'KASUS': 132,
#    'MENINGGAL': 0,
#    'SEMBUH': 606,
#    'tanggal': 1595894400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 2506,
#    'AKUMULASI_KASUS': 6255,
#    'AKUMULASI_MENINGGAL': 201,
#    'AKUMULASI_SEMBUH': 3548,
#    'DIRAWAT_OR_ISOLASI': 47,
#    'KASUS': 97,
#    'MENINGGAL': 2,
#    'SEMBUH': 48,
#    'tanggal': 1595980800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 2312,
#    'AKUMULASI_KASUS': 6396,
#    'AKUMULASI_MENINGGAL': 203,
#    'AKUMULASI_SEMBUH': 3881,
#    'DIRAWAT_OR_ISOLASI': -194,
#    'KASUS': 141,
#    'MENINGGAL': 2,
#    'SEMBUH': 333,
#    'tanggal': 1596067200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 2364,
#    'AKUMULASI_KASUS': 6465,
#    'AKUMULASI_MENINGGAL': 203,
#    'AKUMULASI_SEMBUH': 3898,
#    'DIRAWAT_OR_ISOLASI': 52,
#    'KASUS': 69,
#    'MENINGGAL': 0,
#    'SEMBUH': 17,
#    'tanggal': 1596153600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 2404,
#    'AKUMULASI_KASUS': 6524,
#    'AKUMULASI_MENINGGAL': 203,
#    'AKUMULASI_SEMBUH': 3917,
#    'DIRAWAT_OR_ISOLASI': 40,
#    'KASUS': 59,
#    'MENINGGAL': 0,
#    'SEMBUH': 19,
#    'tanggal': 1596240000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 2454,
#    'AKUMULASI_KASUS': 6581,
#    'AKUMULASI_MENINGGAL': 203,
#    'AKUMULASI_SEMBUH': 3924,
#    'DIRAWAT_OR_ISOLASI': 50,
#    'KASUS': 57,
#    'MENINGGAL': 0,
#    'SEMBUH': 7,
#    'tanggal': 1596326400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 2460,
#    'AKUMULASI_KASUS': 6634,
#    'AKUMULASI_MENINGGAL': 203,
#    'AKUMULASI_SEMBUH': 3971,
#    'DIRAWAT_OR_ISOLASI': 6,
#    'KASUS': 53,
#    'MENINGGAL': 0,
#    'SEMBUH': 47,
#    'tanggal': 1596412800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 2378,
#    'AKUMULASI_KASUS': 6727,
#    'AKUMULASI_MENINGGAL': 208,
#    'AKUMULASI_SEMBUH': 4141,
#    'DIRAWAT_OR_ISOLASI': -82,
#    'KASUS': 93,
#    'MENINGGAL': 5,
#    'SEMBUH': 170,
#    'tanggal': 1596499200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 2493,
#    'AKUMULASI_KASUS': 6851,
#    'AKUMULASI_MENINGGAL': 208,
#    'AKUMULASI_SEMBUH': 4150,
#    'DIRAWAT_OR_ISOLASI': 115,
#    'KASUS': 124,
#    'MENINGGAL': 0,
#    'SEMBUH': 9,
#    'tanggal': 1596585600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 2542,
#    'AKUMULASI_KASUS': 6933,
#    'AKUMULASI_MENINGGAL': 209,
#    'AKUMULASI_SEMBUH': 4182,
#    'DIRAWAT_OR_ISOLASI': 49,
#    'KASUS': 82,
#    'MENINGGAL': 1,
#    'SEMBUH': 32,
#    'tanggal': 1596672000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 2627,
#    'AKUMULASI_KASUS': 7084,
#    'AKUMULASI_MENINGGAL': 213,
#    'AKUMULASI_SEMBUH': 4244,
#    'DIRAWAT_OR_ISOLASI': 85,
#    'KASUS': 151,
#    'MENINGGAL': 4,
#    'SEMBUH': 62,
#    'tanggal': 1596758400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 2825,
#    'AKUMULASI_KASUS': 7325,
#    'AKUMULASI_MENINGGAL': 216,
#    'AKUMULASI_SEMBUH': 4284,
#    'DIRAWAT_OR_ISOLASI': 198,
#    'KASUS': 241,
#    'MENINGGAL': 3,
#    'SEMBUH': 40,
#    'tanggal': 1596844800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 2931,
#    'AKUMULASI_KASUS': 7501,
#    'AKUMULASI_MENINGGAL': 220,
#    'AKUMULASI_SEMBUH': 4350,
#    'DIRAWAT_OR_ISOLASI': 106,
#    'KASUS': 176,
#    'MENINGGAL': 4,
#    'SEMBUH': 66,
#    'tanggal': 1596931200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 2937,
#    'AKUMULASI_KASUS': 7534,
#    'AKUMULASI_MENINGGAL': 220,
#    'AKUMULASI_SEMBUH': 4377,
#    'DIRAWAT_OR_ISOLASI': 6,
#    'KASUS': 33,
#    'MENINGGAL': 0,
#    'SEMBUH': 27,
#    'tanggal': 1597017600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 2986,
#    'AKUMULASI_KASUS': 7626,
#    'AKUMULASI_MENINGGAL': 224,
#    'AKUMULASI_SEMBUH': 4416,
#    'DIRAWAT_OR_ISOLASI': 49,
#    'KASUS': 92,
#    'MENINGGAL': 4,
#    'SEMBUH': 39,
#    'tanggal': 1597104000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 3021,
#    'AKUMULASI_KASUS': 7732,
#    'AKUMULASI_MENINGGAL': 225,
#    'AKUMULASI_SEMBUH': 4486,
#    'DIRAWAT_OR_ISOLASI': 35,
#    'KASUS': 106,
#    'MENINGGAL': 1,
#    'SEMBUH': 70,
#    'tanggal': 1597190400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 3113,
#    'AKUMULASI_KASUS': 7842,
#    'AKUMULASI_MENINGGAL': 226,
#    'AKUMULASI_SEMBUH': 4503,
#    'DIRAWAT_OR_ISOLASI': 92,
#    'KASUS': 110,
#    'MENINGGAL': 1,
#    'SEMBUH': 17,
#    'tanggal': 1597276800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 3453,
#    'AKUMULASI_KASUS': 8204,
#    'AKUMULASI_MENINGGAL': 227,
#    'AKUMULASI_SEMBUH': 4524,
# ...
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 10746,
#    'AKUMULASI_KASUS': 68057,
#    'AKUMULASI_MENINGGAL': 1070,
#    'AKUMULASI_SEMBUH': 56241,
#    'DIRAWAT_OR_ISOLASI': 74,
#    'KASUS': 1256,
#    'MENINGGAL': 6,
#    'SEMBUH': 1176,
#    'tanggal': 1607990400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 11158,
#    'AKUMULASI_KASUS': 69491,
#    'AKUMULASI_MENINGGAL': 1074,
#    'AKUMULASI_SEMBUH': 57259,
#    'DIRAWAT_OR_ISOLASI': 412,
#    'KASUS': 1434,
#    'MENINGGAL': 4,
#    'SEMBUH': 1018,
#    'tanggal': 1608076800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 11525,
#    'AKUMULASI_KASUS': 70768,
#    'AKUMULASI_MENINGGAL': 1087,
#    'AKUMULASI_SEMBUH': 58156,
#    'DIRAWAT_OR_ISOLASI': 367,
#    'KASUS': 1277,
#    'MENINGGAL': 13,
#    'SEMBUH': 897,
#    'tanggal': 1608163200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 11680,
#    'AKUMULASI_KASUS': 71755,
#    'AKUMULASI_MENINGGAL': 1088,
#    'AKUMULASI_SEMBUH': 58987,
#    'DIRAWAT_OR_ISOLASI': 155,
#    'KASUS': 987,
#    'MENINGGAL': 1,
#    'SEMBUH': 831,
#    'tanggal': 1608249600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 12075,
#    'AKUMULASI_KASUS': 72887,
#    'AKUMULASI_MENINGGAL': 1089,
#    'AKUMULASI_SEMBUH': 59723,
#    'DIRAWAT_OR_ISOLASI': 395,
#    'KASUS': 1132,
#    'MENINGGAL': 1,
#    'SEMBUH': 736,
#    'tanggal': 1608336000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 11940,
#    'AKUMULASI_KASUS': 73939,
#    'AKUMULASI_MENINGGAL': 1090,
#    'AKUMULASI_SEMBUH': 60909,
#    'DIRAWAT_OR_ISOLASI': -135,
#    'KASUS': 1052,
#    'MENINGGAL': 1,
#    'SEMBUH': 1186,
#    'tanggal': 1608422400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 12022,
#    'AKUMULASI_KASUS': 74655,
#    'AKUMULASI_MENINGGAL': 1094,
#    'AKUMULASI_SEMBUH': 61539,
#    'DIRAWAT_OR_ISOLASI': 82,
#    'KASUS': 716,
#    'MENINGGAL': 4,
#    'SEMBUH': 630,
#    'tanggal': 1608508800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 12173,
#    'AKUMULASI_KASUS': 75580,
#    'AKUMULASI_MENINGGAL': 1097,
#    'AKUMULASI_SEMBUH': 62310,
#    'DIRAWAT_OR_ISOLASI': 151,
#    'KASUS': 925,
#    'MENINGGAL': 3,
#    'SEMBUH': 771,
#    'tanggal': 1608595200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 12134,
#    'AKUMULASI_KASUS': 76483,
#    'AKUMULASI_MENINGGAL': 1099,
#    'AKUMULASI_SEMBUH': 63250,
#    'DIRAWAT_OR_ISOLASI': -39,
#    'KASUS': 903,
#    'MENINGGAL': 2,
#    'SEMBUH': 940,
#    'tanggal': 1608681600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 12310,
#    'AKUMULASI_KASUS': 77185,
#    'AKUMULASI_MENINGGAL': 1109,
#    'AKUMULASI_SEMBUH': 63766,
#    'DIRAWAT_OR_ISOLASI': 176,
#    'KASUS': 702,
#    'MENINGGAL': 10,
#    'SEMBUH': 516,
#    'tanggal': 1608768000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 12496,
#    'AKUMULASI_KASUS': 78088,
#    'AKUMULASI_MENINGGAL': 1109,
#    'AKUMULASI_SEMBUH': 64483,
#    'DIRAWAT_OR_ISOLASI': 186,
#    'KASUS': 903,
#    'MENINGGAL': 0,
#    'SEMBUH': 717,
#    'tanggal': 1608854400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 12419,
#    'AKUMULASI_KASUS': 78689,
#    'AKUMULASI_MENINGGAL': 1109,
#    'AKUMULASI_SEMBUH': 65161,
#    'DIRAWAT_OR_ISOLASI': -77,
#    'KASUS': 601,
#    'MENINGGAL': 0,
#    'SEMBUH': 678,
#    'tanggal': 1608940800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 12096,
#    'AKUMULASI_KASUS': 79581,
#    'AKUMULASI_MENINGGAL': 1152,
#    'AKUMULASI_SEMBUH': 66333,
#    'DIRAWAT_OR_ISOLASI': -323,
#    'KASUS': 892,
#    'MENINGGAL': 43,
#    'SEMBUH': 1172,
#    'tanggal': 1609027200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 11667,
#    'AKUMULASI_KASUS': 79984,
#    'AKUMULASI_MENINGGAL': 1152,
#    'AKUMULASI_SEMBUH': 67165,
#    'DIRAWAT_OR_ISOLASI': -429,
#    'KASUS': 403,
#    'MENINGGAL': 0,
#    'SEMBUH': 832,
#    'tanggal': 1609113600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 11836,
#    'AKUMULASI_KASUS': 81313,
#    'AKUMULASI_MENINGGAL': 1154,
#    'AKUMULASI_SEMBUH': 68323,
#    'DIRAWAT_OR_ISOLASI': 169,
#    'KASUS': 1329,
#    'MENINGGAL': 2,
#    'SEMBUH': 1158,
#    'tanggal': 1609200000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 11878,
#    'AKUMULASI_KASUS': 82546,
#    'AKUMULASI_MENINGGAL': 1156,
#    'AKUMULASI_SEMBUH': 69512,
#    'DIRAWAT_OR_ISOLASI': 42,
#    'KASUS': 1233,
#    'MENINGGAL': 2,
#    'SEMBUH': 1189,
#    'tanggal': 1609286400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 11644,
#    'AKUMULASI_KASUS': 83570,
#    'AKUMULASI_MENINGGAL': 1167,
#    'AKUMULASI_SEMBUH': 70759,
#    'DIRAWAT_OR_ISOLASI': -234,
#    'KASUS': 1024,
#    'MENINGGAL': 11,
#    'SEMBUH': 1247,
#    'tanggal': 1609372800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 11938,
#    'AKUMULASI_KASUS': 85074,
#    'AKUMULASI_MENINGGAL': 1170,
#    'AKUMULASI_SEMBUH': 71966,
#    'DIRAWAT_OR_ISOLASI': 294,
#    'KASUS': 1504,
#    'MENINGGAL': 3,
#    'SEMBUH': 1207,
#    'tanggal': 1609459200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 12190,
#    'AKUMULASI_KASUS': 86241,
#    'AKUMULASI_MENINGGAL': 1171,
#    'AKUMULASI_SEMBUH': 72880,
#    'DIRAWAT_OR_ISOLASI': 252,
#    'KASUS': 1167,
#    'MENINGGAL': 1,
#    'SEMBUH': 914,
#    'tanggal': 1609545600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 12303,
#    'AKUMULASI_KASUS': 87473,
#    'AKUMULASI_MENINGGAL': 1173,
#    'AKUMULASI_SEMBUH': 73997,
#    'DIRAWAT_OR_ISOLASI': 113,
#    'KASUS': 1232,
#    'MENINGGAL': 2,
#    'SEMBUH': 1117,
#    'tanggal': 1609632000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 12336,
#    'AKUMULASI_KASUS': 88552,
#    'AKUMULASI_MENINGGAL': 1175,
#    'AKUMULASI_SEMBUH': 75041,
#    'DIRAWAT_OR_ISOLASI': 33,
#    'KASUS': 1079,
#    'MENINGGAL': 2,
#    'SEMBUH': 1044,
#    'tanggal': 1609718400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 12345,
#    'AKUMULASI_KASUS': 89652,
#    'AKUMULASI_MENINGGAL': 1183,
#    'AKUMULASI_SEMBUH': 76124,
#    'DIRAWAT_OR_ISOLASI': 9,
#    'KASUS': 1100,
#    'MENINGGAL': 8,
#    'SEMBUH': 1083,
#    'tanggal': 1609804800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 12441,
#    'AKUMULASI_KASUS': 91122,
#    'AKUMULASI_MENINGGAL': 1194,
#    'AKUMULASI_SEMBUH': 77487,
#    'DIRAWAT_OR_ISOLASI': 96,
#    'KASUS': 1470,
#    'MENINGGAL': 11,
#    'SEMBUH': 1363,
#    'tanggal': 1609891200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 12649,
#    'AKUMULASI_KASUS': 92538,
#    'AKUMULASI_MENINGGAL': 1196,
#    'AKUMULASI_SEMBUH': 78693,
#    'DIRAWAT_OR_ISOLASI': 208,
#    'KASUS': 1416,
#    'MENINGGAL': 2,
#    'SEMBUH': 1206,
#    'tanggal': 1609977600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 13557,
#    'AKUMULASI_KASUS': 94362,
#    'AKUMULASI_MENINGGAL': 1200,
#    'AKUMULASI_SEMBUH': 79605,
#    'DIRAWAT_OR_ISOLASI': 908,
#    'KASUS': 1824,
#    'MENINGGAL': 4,
#    'SEMBUH': 912,
#    'tanggal': 1610064000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 14104,
#    'AKUMULASI_KASUS': 96093,
#    'AKUMULASI_MENINGGAL': 1206,
#    'AKUMULASI_SEMBUH': 80783,
#    'DIRAWAT_OR_ISOLASI': 547,
#    'KASUS': 1731,
#    'MENINGGAL': 6,
#    'SEMBUH': 1178,
#    'tanggal': 1610150400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 14613,
#    'AKUMULASI_KASUS': 97560,
#    'AKUMULASI_MENINGGAL': 1214,
#    'AKUMULASI_SEMBUH': 81733,
#    'DIRAWAT_OR_ISOLASI': 509,
#    'KASUS': 1467,
#    'MENINGGAL': 8,
#    'SEMBUH': 950,
#    'tanggal': 1610236800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 15017,
#    'AKUMULASI_KASUS': 99035,
#    'AKUMULASI_MENINGGAL': 1225,
#    'AKUMULASI_SEMBUH': 82793,
#    'DIRAWAT_OR_ISOLASI': 404,
#    'KASUS': 1475,
#    'MENINGGAL': 11,
#    'SEMBUH': 1060,
#    'tanggal': 1610323200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 15574,
#    'AKUMULASI_KASUS': 100575,
#    'AKUMULASI_MENINGGAL': 1240,
#    'AKUMULASI_SEMBUH': 83761,
#    'DIRAWAT_OR_ISOLASI': 557,
#    'KASUS': 1540,
#    'MENINGGAL': 15,
#    'SEMBUH': 968,
#    'tanggal': 1610409600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 16256,
#    'AKUMULASI_KASUS': 102330,
#    'AKUMULASI_MENINGGAL': 1251,
#    'AKUMULASI_SEMBUH': 84823,
#    'DIRAWAT_OR_ISOLASI': 682,
#    'KASUS': 1755,
#    'MENINGGAL': 11,
#    'SEMBUH': 1062,
#    'tanggal': 1610496000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 17098,
#    'AKUMULASI_KASUS': 104532,
#    'AKUMULASI_MENINGGAL': 1262,
#    'AKUMULASI_SEMBUH': 86172,
#    'DIRAWAT_OR_ISOLASI': 842,
#    'KASUS': 2202,
#    'MENINGGAL': 11,
#    'SEMBUH': 1349,
#    'tanggal': 1610582400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 19074,
#    'AKUMULASI_KASUS': 107627,
#    'AKUMULASI_MENINGGAL': 1289,
#    'AKUMULASI_SEMBUH': 87264,
#    'DIRAWAT_OR_ISOLASI': 1976,
#    'KASUS': 3095,
#    'MENINGGAL': 27,
#    'SEMBUH': 1092,
#    'tanggal': 1610668800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 20349,
#    'AKUMULASI_KASUS': 111087,
#    'AKUMULASI_MENINGGAL': 1331,
#    'AKUMULASI_SEMBUH': 89407,
#    'DIRAWAT_OR_ISOLASI': 1275,
#    'KASUS': 3460,
#    'MENINGGAL': 42,
#    'SEMBUH': 2143,
#    'tanggal': 1610755200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 20247,
#    'AKUMULASI_KASUS': 112578,
#    'AKUMULASI_MENINGGAL': 1342,
#    'AKUMULASI_SEMBUH': 90989,
#    'DIRAWAT_OR_ISOLASI': -102,
#    'KASUS': 1491,
#    'MENINGGAL': 11,
#    'SEMBUH': 1582,
#    'tanggal': 1610841600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 20079,
#    'AKUMULASI_KASUS': 114063,
#    'AKUMULASI_MENINGGAL': 1370,
#    'AKUMULASI_SEMBUH': 92614,
#    'DIRAWAT_OR_ISOLASI': -168,
#    'KASUS': 1485,
#    'MENINGGAL': 28,
#    'SEMBUH': 1625,
#    'tanggal': 1610928000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 20377,
#    'AKUMULASI_KASUS': 115747,
#    'AKUMULASI_MENINGGAL': 1394,
#    'AKUMULASI_SEMBUH': 93976,
#    'DIRAWAT_OR_ISOLASI': 298,
#    'KASUS': 1684,
#    'MENINGGAL': 24,
#    'SEMBUH': 1362,
#    'tanggal': 1611014400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 20689,
#    'AKUMULASI_KASUS': 117561,
#    'AKUMULASI_MENINGGAL': 1407,
#    'AKUMULASI_SEMBUH': 95465,
#    'DIRAWAT_OR_ISOLASI': 312,
#    'KASUS': 1814,
#    'MENINGGAL': 13,
#    'SEMBUH': 1489,
#    'tanggal': 1611100800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 20249,
#    'AKUMULASI_KASUS': 118789,
#    'AKUMULASI_MENINGGAL': 1480,
#    'AKUMULASI_SEMBUH': 97060,
#    'DIRAWAT_OR_ISOLASI': -440,
#    'KASUS': 1228,
#    'MENINGGAL': 73,
#    'SEMBUH': 1595,
#    'tanggal': 1611187200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 21321,
#    'AKUMULASI_KASUS': 121230,
#    'AKUMULASI_MENINGGAL': 1488,
#    'AKUMULASI_SEMBUH': 98421,
#    'DIRAWAT_OR_ISOLASI': 1072,
#    'KASUS': 2441,
#    'MENINGGAL': 8,
#    'SEMBUH': 1361,
#    'tanggal': 1611273600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 20995,
#    'AKUMULASI_KASUS': 123039,
#    'AKUMULASI_MENINGGAL': 1504,
#    'AKUMULASI_SEMBUH': 100540,
#    'DIRAWAT_OR_ISOLASI': -326,
#    'KASUS': 1809,
#    'MENINGGAL': 16,
#    'SEMBUH': 2119,
#    'tanggal': 1611360000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 21549,
#    'AKUMULASI_KASUS': 125367,
#    'AKUMULASI_MENINGGAL': 1512,
#    'AKUMULASI_SEMBUH': 102306,
#    'DIRAWAT_OR_ISOLASI': 554,
#    'KASUS': 2328,
#    'MENINGGAL': 8,
#    'SEMBUH': 1766,
#    'tanggal': 1611446400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 22336,
#    'AKUMULASI_KASUS': 127389,
#    'AKUMULASI_MENINGGAL': 1514,
#    'AKUMULASI_SEMBUH': 103539,
#    'DIRAWAT_OR_ISOLASI': 787,
#    'KASUS': 2022,
#    'MENINGGAL': 2,
#    'SEMBUH': 1233,
#    'tanggal': 1611532800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 23999,
#    'AKUMULASI_KASUS': 131313,
#    'AKUMULASI_MENINGGAL': 1527,
#    'AKUMULASI_SEMBUH': 105787,
#    'DIRAWAT_OR_ISOLASI': 1663,
#    'KASUS': 3924,
#    'MENINGGAL': 13,
#    'SEMBUH': 2248,
#    'tanggal': 1611619200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 25292,
#    'AKUMULASI_KASUS': 134511,
#    'AKUMULASI_MENINGGAL': 1633,
#    'AKUMULASI_SEMBUH': 107586,
#    'DIRAWAT_OR_ISOLASI': 1293,
#    'KASUS': 3198,
#    'MENINGGAL': 106,
#    'SEMBUH': 1799,
#    'tanggal': 1611705600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 27369,
#    'AKUMULASI_KASUS': 139044,
#    'AKUMULASI_MENINGGAL': 1796,
#    'AKUMULASI_SEMBUH': 109879,
#    'DIRAWAT_OR_ISOLASI': 2077,
#    'KASUS': 4533,
#    'MENINGGAL': 163,
#    'SEMBUH': 2293,
#    'tanggal': 1611792000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 28960,
#    'AKUMULASI_KASUS': 142878,
#    'AKUMULASI_MENINGGAL': 1801,
#    'AKUMULASI_SEMBUH': 112117,
#    'DIRAWAT_OR_ISOLASI': 1591,
#    'KASUS': 3834,
#    'MENINGGAL': 5,
#    'SEMBUH': 2238,
#    'tanggal': 1611878400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 30873,
#    'AKUMULASI_KASUS': 147479,
#    'AKUMULASI_MENINGGAL': 1828,
#    'AKUMULASI_SEMBUH': 114778,
#    'DIRAWAT_OR_ISOLASI': 1913,
#    'KASUS': 4601,
#    'MENINGGAL': 27,
#    'SEMBUH': 2661,
#    'tanggal': 1611964800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 31199,
#    'AKUMULASI_KASUS': 150327,
#    'AKUMULASI_MENINGGAL': 1890,
#    'AKUMULASI_SEMBUH': 117238,
#    'DIRAWAT_OR_ISOLASI': 326,
#    'KASUS': 2848,
#    'MENINGGAL': 62,
#    'SEMBUH': 2460,
#    'tanggal': 1612051200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 31615,
#    'AKUMULASI_KASUS': 153295,
#    'AKUMULASI_MENINGGAL': 1895,
#    'AKUMULASI_SEMBUH': 119785,
#    'DIRAWAT_OR_ISOLASI': 416,
#    'KASUS': 2968,
#    'MENINGGAL': 5,
#    'SEMBUH': 2547,
#    'tanggal': 1612137600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 31295,
#    'AKUMULASI_KASUS': 155363,
#    'AKUMULASI_MENINGGAL': 1973,
#    'AKUMULASI_SEMBUH': 122095,
#    'DIRAWAT_OR_ISOLASI': -320,
#    'KASUS': 2068,
#    'MENINGGAL': 78,
#    'SEMBUH': 2310,
#    'tanggal': 1612224000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 31635,
#    'AKUMULASI_KASUS': 157604,
#    'AKUMULASI_MENINGGAL': 1983,
#    'AKUMULASI_SEMBUH': 123986,
#    'DIRAWAT_OR_ISOLASI': 340,
#    'KASUS': 2241,
#    'MENINGGAL': 10,
#    'SEMBUH': 1891,
#    'tanggal': 1612310400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 31274,
#    'AKUMULASI_KASUS': 159625,
#    'AKUMULASI_MENINGGAL': 2000,
#    'AKUMULASI_SEMBUH': 126351,
#    'DIRAWAT_OR_ISOLASI': -361,
#    'KASUS': 2021,
#    'MENINGGAL': 17,
#    'SEMBUH': 2365,
#    'tanggal': 1612396800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 30688,
#    'AKUMULASI_KASUS': 161742,
#    'AKUMULASI_MENINGGAL': 2028,
#    'AKUMULASI_SEMBUH': 129026,
#    'DIRAWAT_OR_ISOLASI': -586,
#    'KASUS': 2117,
#    'MENINGGAL': 28,
#    'SEMBUH': 2675,
#    'tanggal': 1612483200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 31538,
#    'AKUMULASI_KASUS': 165713,
#    'AKUMULASI_MENINGGAL': 2032,
#    'AKUMULASI_SEMBUH': 132143,
#    'DIRAWAT_OR_ISOLASI': 850,
#    'KASUS': 3971,
#    'MENINGGAL': 4,
#    'SEMBUH': 3117,
#    'tanggal': 1612569600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 31422,
#    'AKUMULASI_KASUS': 167699,
#    'AKUMULASI_MENINGGAL': 2034,
#    'AKUMULASI_SEMBUH': 134243,
#    'DIRAWAT_OR_ISOLASI': -116,
#    'KASUS': 1986,
#    'MENINGGAL': 2,
#    'SEMBUH': 2100,
#    'tanggal': 1612656000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 29688,
#    'AKUMULASI_KASUS': 169199,
#    'AKUMULASI_MENINGGAL': 2046,
#    'AKUMULASI_SEMBUH': 137465,
#    'DIRAWAT_OR_ISOLASI': -1734,
#    'KASUS': 1500,
#    'MENINGGAL': 12,
#    'SEMBUH': 3222,
#    'tanggal': 1612742400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 28319,
#    'AKUMULASI_KASUS': 169975,
#    'AKUMULASI_MENINGGAL': 2063,
#    'AKUMULASI_SEMBUH': 139593,
#    'DIRAWAT_OR_ISOLASI': -1369,
#    'KASUS': 776,
#    'MENINGGAL': 17,
#    'SEMBUH': 2128,
#    'tanggal': 1612828800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 27904,
#    'AKUMULASI_KASUS': 170635,
#    'AKUMULASI_MENINGGAL': 2079,
#    'AKUMULASI_SEMBUH': 140652,
#    'DIRAWAT_OR_ISOLASI': -415,
#    'KASUS': 660,
#    'MENINGGAL': 16,
#    'SEMBUH': 1059,
#    'tanggal': 1612915200000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 27818,
#    'AKUMULASI_KASUS': 171694,
#    'AKUMULASI_MENINGGAL': 2097,
#    'AKUMULASI_SEMBUH': 141779,
#    'DIRAWAT_OR_ISOLASI': -86,
#    'KASUS': 1059,
#    'MENINGGAL': 18,
#    'SEMBUH': 1127,
#    'tanggal': 1613001600000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 26913,
#    'AKUMULASI_KASUS': 172377,
#    'AKUMULASI_MENINGGAL': 2102,
#    'AKUMULASI_SEMBUH': 143362,
#    'DIRAWAT_OR_ISOLASI': -905,
#    'KASUS': 683,
#    'MENINGGAL': 5,
#    'SEMBUH': 1583,
#    'tanggal': 1613088000000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 26164,
#    'AKUMULASI_KASUS': 174113,
#    'AKUMULASI_MENINGGAL': 2104,
#    'AKUMULASI_SEMBUH': 145845,
#    'DIRAWAT_OR_ISOLASI': -749,
#    'KASUS': 1736,
#    'MENINGGAL': 2,
#    'SEMBUH': 2483,
#    'tanggal': 1613174400000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 25347,
#    'AKUMULASI_KASUS': 174994,
#    'AKUMULASI_MENINGGAL': 2108,
#    'AKUMULASI_SEMBUH': 147539,
#    'DIRAWAT_OR_ISOLASI': -817,
#    'KASUS': 881,
#    'MENINGGAL': 4,
#    'SEMBUH': 1694,
#    'tanggal': 1613260800000},
#   {'AKUMULASI_DIRAWAT_OR_ISOLASI': 25024,
#    'AKUMULASI_KASUS': 175941,
#    'AKUMULASI_MENINGGAL': 2113,
#    'AKUMULASI_SEMBUH': 148804,
#    'DIRAWAT_OR_ISOLASI': -323,
#    'KASUS': 947,
#    'MENINGGAL': 5,
#    'SEMBUH': 1265,
#    'tanggal': 1613347200000}],
#  'meninggal_dengan_tgl': 2113,
#  'meninggal_persen': 1.2037510656436488,
#  'meninggal_tanpa_tgl': 5,
#  'provinsi': 'JAWA BARAT',
#  'sembuh_dengan_tgl': 148804,
#  'sembuh_persen': 84.59960215970446,
#  'sembuh_tanpa_tgl': 49}

# %% [markdown]
# ### **Memahami Kasus COVID-19 di Jawa Barat**
# Sekarang jalankanlah method **keys()** pada **cov_jabar_raw** tersebut untuk mengetahui nama-nama elemen utama yang tersedia dan jawablah pertanyaan berikut:
#
# * Berapa jumlah total kasus COVID-19 di Jawa Barat?
# * Berapa persentase kematian akibat COVID-19 di Jawa Barat?
# * Berapa persentase tingkat kesembuhan dari COVID-19 di Jawa Barat?

# %%
print('Nama-nama elemen utama:\n', cov_jabar_raw.keys())
print('\nJumlah total kasus COVID-19 di Jawa Barat : %d' %cov_jabar_raw['kasus_total'])
print('Persentase kematian akibat COVID-19 di Jawa Barat : %f.2%%' %cov_jabar_raw['meninggal_persen'])
print('Persentase tingkat kesembuhan dari COVID-19 di Jawa Barat : %f.2%%' %cov_jabar_raw['sembuh_persen'])
# Out:
# Nama-nama elemen utama:
#  dict_keys(['last_date', 'provinsi', 'kasus_total', 'kasus_tanpa_tgl', 'kasus_dengan_tgl', 'meninggal_persen', 'meninggal_tanpa_tgl', 'meninggal_dengan_tgl', 'sembuh_persen', 'sembuh_tanpa_tgl', 'sembuh_dengan_tgl', 'list_perkembangan', 'data'])
#
# Jumlah total kasus COVID-19 di Jawa Barat : 175950
# Persentase kematian akibat COVID-19 di Jawa Barat : 1.203751.2%
# Persentase tingkat kesembuhan dari COVID-19 di Jawa Barat : 84.599602.2%

# %% [markdown]
# ### **Memperoleh Informasi yang Lebih Lengkap**
# Informasi umum mengenai COVID-19 di Jawa Barat telah Anda dapatkan. Namun informasi akan lebih lengkap jika Anda memiliki data perkembangan COVID-19 dari waktu ke waktu, apakah Anda setuju?
#
# Kabar baiknya adalah informasi tersebut juga disediakan oleh covid19.go.id melalui permintaan API yang telah Anda buat sebelumnya. Data historis perkembangan COVID-19 tersebut tersimpan dengan nama **list_perkembangan**. Silakan Anda ekstrak data tersebut dari **cov_jabar_raw** dan untuk lebih memudahkan dalam menginspeksi data ubahlah data bertipe **dict ke pandas dataframe**. Kemudian simpanlah hasilnya sebagai obyek bernama **cov_jabar**!
#
# **Amati** struktur cov_jabar menggunakan method **info()** dan **head()**.

# %%
import numpy as np
import pandas as pd
cov_jabar = pd.DataFrame(cov_jabar_raw['list_perkembangan'])
print('Info cov_jabar:\n', cov_jabar.info())
print('\nLima data teratas cov_jabar:\n', cov_jabar.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   tanggal                       351 non-null    int64
#  1   KASUS                         351 non-null    int64
#  2   MENINGGAL                     351 non-null    int64
#  3   SEMBUH                        351 non-null    int64
#  4   DIRAWAT_OR_ISOLASI            351 non-null    int64
#  5   AKUMULASI_KASUS               351 non-null    int64
#  6   AKUMULASI_SEMBUH              351 non-null    int64
#  7   AKUMULASI_MENINGGAL           351 non-null    int64
#  8   AKUMULASI_DIRAWAT_OR_ISOLASI  351 non-null    int64
# dtypes: int64(9)
# memory usage: 24.8 KB
# Info cov_jabar:
#  None
#
# Lima data teratas cov_jabar:
#           tanggal  KASUS  ...  AKUMULASI_MENINGGAL  AKUMULASI_DIRAWAT_OR_ISOLASI
# 0  1583107200000      3  ...                    0                             3
# 1  1583193600000      1  ...                    1                             3
# 2  1583280000000      1  ...                    1                             4
# 3  1583366400000      1  ...                    1                             5
# 4  1583452800000      1  ...                    1                             6
#
# [5 rows x 9 columns]

# %%
cov_jabar
# Out:
#            tanggal  KASUS  ...  AKUMULASI_MENINGGAL  AKUMULASI_DIRAWAT_OR_ISOLASI
# 0    1583107200000      3  ...                    0                             3
# 1    1583193600000      1  ...                    1                             3
# 2    1583280000000      1  ...                    1                             4
# 3    1583366400000      1  ...                    1                             5
# 4    1583452800000      1  ...                    1                             6
# ..             ...    ...  ...                  ...                           ...
# 346  1613001600000   1059  ...                 2097                         27818
# 347  1613088000000    683  ...                 2102                         26913
# 348  1613174400000   1736  ...                 2104                         26164
# 349  1613260800000    881  ...                 2108                         25347
# 350  1613347200000    947  ...                 2113                         25024
#
# [351 rows x 9 columns]

# %% [markdown]
# ### **Menjinakkan Data**
# Setelah mengekstrak dan mengamati cov_jabar, Anda menemukan beberapa kejanggalan pada data tersebut. Diantaranya adalah kejanggalan data pada kolom tanggal dan format penulisan kolom yang tidak konsisten. Sekarang Anda akan mencoba melakukan beberapa tahapan untuk menjinakan data tersebut sehingga dapat diolah dan dianalisis dengan lebih mudah.
#
# Ada beberapa tahapan yang akan Anda lakukan untuk menjinakan data cov_jabar, yaitu:
#
# * Menghapus kolom DIRAWAT_OR_ISOLASI dan semua kolom yang berisi nilai kumulatif
# * Merubah format penulisan semua kolom menjadi huruf kecil
# * Mengganti nama kolom kasus menjadi kasus_baru
# * Memperbaiki tipe data pada kolom tanggal menggunakan pd.to_datetime
#
# Lengkapilah baris kode berikut untuk melakukan menjinakan data sesuai dengan tahapan yang telah Anda rencanakan! Anda akan menggunakan teknik chaining pada dataframe. Simpan hasil pengolahan Anda dengan nama **cov_jabar_tidy**.

# %%
cov_jabar_tidy = (cov_jabar.drop(columns=[item for item in cov_jabar.columns
                                                        if item.startswith('AKUMULASI')
                                                          or item.startswith('DIRAWAT')])
                                              .rename(columns=str.lower)
                                              .rename(columns={'kasus': 'kasus_baru'})
)

cov_jabar_tidy['tanggal'] = pd.to_datetime(cov_jabar_tidy['tanggal']*1e6, unit='ns')
print('Lima data teratas:\n', cov_jabar_tidy.head())
# Out:
# Lima data teratas:
#       tanggal  kasus_baru  meninggal  sembuh
# 0 2020-03-02           3          0       0
# 1 2020-03-03           1          1       0
# 2 2020-03-04           1          0       0
# 3 2020-03-05           1          0       0
# 4 2020-03-06           1          0       0

# %%
cov_jabar_tidy
# Out:
#        tanggal  kasus_baru  meninggal  sembuh
# 0   2020-03-02           3          0       0
# 1   2020-03-03           1          1       0
# 2   2020-03-04           1          0       0
# 3   2020-03-05           1          0       0
# 4   2020-03-06           1          0       0
# ..         ...         ...        ...     ...
# 346 2021-02-11        1059         18    1127
# 347 2021-02-12         683          5    1583
# 348 2021-02-13        1736          2    2483
# 349 2021-02-14         881          4    1694
# 350 2021-02-15         947          5    1265
#
# [351 rows x 4 columns]

# %% [markdown]
# ### **Menunjukkan Melalui Gambar**
# Akhirnya Anda berhasil menjinakan data cov_jabar menjadi cov_jabar_tidy sehingga lebih mudah untuk diolah, selamat! Memiliki data yang rapi memang menyenangkan, apakah Anda setuju dengan hal tersebut?
#
# Setelah memiliki data yang jinak, sekarang saatnya Anda mengekspresikan data tersebut dalam bentuk lain yang harapannya lebih mudah dicerna: grafik. Anda akan memulai merancang visualisasi yang memiliki estetika dengan menggunakan library matplotlib. Imporlah library tersebut sebagai aliasnya!

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### **Menunjukkan Melalui Gambar - 2**
# Berikut merupakan template kode untuk membuat visualisasi menggunakan matplotlib:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Berdasarkan templat tersebut, komponen utama untuk membuat visualisasi antara lain adalah tabel data, kolom data, serta bentuk geometri untuk mempresentasikan data. Sebagai contoh untuk membuat scatter-plot yang diperlukan adalah bentuk geometri titik **(.scatter())**, line-chart memerlukan geometri garis **(.plot())**, sedangkan bar-chart memerlukan bentuk geometri batang atau kolom **(.bar())**.

# %% [markdown]
# Lengkapi baris kode berikut untuk membuat bar-chart jumlah kasus baru harian COVID-19 di Jawa Barat menggunakan data **cov_jabar_tidy**! Pergunakan kolom **tanggal** sebagai sumbu-x.

# %%
import matplotlib.pyplot as plt

plt.clf()
fig, ax = plt.subplots(figsize=(10,5))
ax.bar(data=cov_jabar_tidy, x='tanggal', height='kasus_baru')
plt.show()

# %% [markdown]
# ### **Informasi pada Grafik**
# Anda telah berhasil membuat bar-chart yang diminta. Namun grafik tersebut belum memiliki informasi yang jelas serta cenderung membosankan untuk dilihat. Sekarang silakan buat kembali grafik tersebut dengan menggunakan baris kode yang telah dimodifikasi berikut:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

plt.clf()
fig, ax = plt.subplots(figsize=(10,5))
ax.bar(data=cov_jabar_tidy, x='tanggal', height='kasus_baru', color='salmon')
fig.suptitle('Kasus Harian Positif COVID-19 di Jawa Barat',
             y=1.00, fontsize=16, fontweight='bold', ha='center')
ax.set_title('Terjadi pelonjakan kasus di awal bulan Juli akibat klaster Secapa AD Bandung',
             fontsize=10)
ax.set_xlabel('')
ax.set_ylabel('Jumlah kasus')
ax.text(1, -0.1, 'Sumber data: covid.19.go.id', color='blue',
        ha='right', transform=ax.transAxes)

ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))

plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Grafik untuk Kasus Sembuh**
# Sekarang buatlah grafik serupa dengan menggunakan data **kasus sembuh** menggunakan warna **olivedrab**!

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

plt.clf()
fig, ax = plt.subplots(figsize=(10,5))
ax.bar(data=cov_jabar_tidy, x='tanggal', height='sembuh', color='olivedrab')
ax.set_title('Kasus Harian Sembuh Dari COVID-19 di Jawa Barat',
             fontsize=22)
ax.set_xlabel('')
ax.set_ylabel('Jumlah kasus')
ax.text(1, -0.1, 'Sumber data: covid.19.go.id', color='blue',
ha='right', transform=ax.transAxes)

ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))

plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Grafik untuk Kasus Meninggal**
# Sekarang buatlah grafik serupa dengan menggunakan data **kasus meninggal** menggunakan **warna slategrey**!

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

plt.clf()
fig, ax = plt.subplots(figsize=(10,5))
ax.bar(data=cov_jabar_tidy, x='tanggal', height='meninggal', color='slategrey')
ax.set_title('Kasus Harian Meninggal Dari COVID-19 di Jawa Barat',
             fontsize=22)
ax.set_xlabel('')
ax.set_ylabel('Jumlah kasus')
ax.text(1, -0.1, 'Sumber data: covid.19.go.id', color='blue',
ha='right', transform=ax.transAxes)

ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))

plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Menggali Lebih Dalam**

# %% [markdown]
# ### **Apakah Pekan ini Lebih Baik?**
# Setelah mengamati grafik perkembangan kasus Anda menyadari bahwa terjadi fluktuasi pertambahan kasus harian. Dilandasi hal tersebut Anda kemudian ingin mencoba mengamati bagaimana perkembangan kasus dalam rentang waktu pekanan. Bagaimanakah caranya?
#
# Anda dapat dengan mudah mengerjakannya Anda sudah dibantu melalui predefined code, yaitu set terlebih dahulu **kolom tanggal** pada **cov_jabar_tidy** sebagai **index**. Kemudian terapkan method pada time series di pandas, resampling per pekan dan gunakan agregasi penjumlahan. Adapun yang akan digunakan untuk mengekstrak informasi pekan dalam satu tahun adalah **weekofyear** dan **year** untuk tahun.
#
# Lengkapilah baris kode berikut untuk menghitung pertambahan kasus pekanan dan simpanlah hasilnya sebagai **cov_jabar_pekanan**! Anda juga diminta untuk menggunakan method **info()** dan **.head()** untuk melakukan inspeksi data.

# %%
cov_jabar_pekanan = (cov_jabar_tidy.set_index('tanggal')['kasus_baru']
                                   .resample('W')
                                   .sum()
                                   .reset_index()
                                   .rename(columns={'kasus_baru': 'jumlah'})
                    )
cov_jabar_pekanan['tahun'] = cov_jabar_pekanan['tanggal'].apply(lambda x: x.year)
cov_jabar_pekanan['pekan_ke'] = cov_jabar_pekanan['tanggal'].apply(lambda x: x.weekofyear)
cov_jabar_pekanan = cov_jabar_pekanan[['tahun', 'pekan_ke', 'jumlah']]

print('Info cov_jabar_pekanan:')
print(cov_jabar_pekanan.info())
print('\nLima data teratas cov_jabar_pekanan:\n', cov_jabar_pekanan.head())
# Out:
# Info cov_jabar_pekanan:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tahun     51 non-null     int64
#  1   pekan_ke  51 non-null     int64
#  2   jumlah    51 non-null     int64
# dtypes: int64(3)
# memory usage: 1.3 KB
# None
#
# Lima data teratas cov_jabar_pekanan:
#     tahun  pekan_ke  jumlah
# 0   2020        10       7
# 1   2020        11       5
# 2   2020        12      52
# 3   2020        13     104
# 4   2020        14     122

# %%
cov_jabar_pekanan
# Out:
#     tahun  pekan_ke  jumlah
# 0    2020        10       7
# 1    2020        11       5
# 2    2020        12      52
# 3    2020        13     104
# 4    2020        14     122
# 5    2020        15     235
# 6    2020        16     277
# 7    2020        17     216
# 8    2020        18     156
# 9    2020        19     367
# 10   2020        20     216
# 11   2020        21     399
# 12   2020        22     182
# 13   2020        23     133
# 14   2020        24     191
# 15   2020        25     259
# 16   2020        26     247
# 17   2020        27     466
# 18   2020        28    1494
# 19   2020        29     411
# 20   2020        30     430
# 21   2020        31     612
# 22   2020        32     920
# 23   2020        33    1008
# 24   2020        34     703
# 25   2020        35    1660
# 26   2020        36    1567
# 27   2020        37    1872
# 28   2020        38    2441
# 29   2020        39    4150
# 30   2020        40    2952
# 31   2020        41    3322
# 32   2020        42    3047
# 33   2020        43    3648
# 34   2020        44    2688
# 35   2020        45    3523
# 36   2020        46    4395
# 37   2020        47    3579
# 38   2020        48    3711
# 39   2020        49    7497
# 40   2020        50    6937
# 41   2020        51    7738
# 42   2020        52    5642
# 43   2021        53    7892
# 44   2021         1   10087
# 45   2021         2   15018
# 46   2021         3   12789
# 47   2021         4   24960
# 48   2021         5   17372
# 49   2021         6    7295
# 50   2021         7     947

# %% [markdown]
# ### **Menjawab Pertanyaan**
# Pertanyaan baru muncul di benak Anda setelah melakukan inspeksi terhadap data cov_jabar_pekanan tersebut: "Apakah pekan ini lebih baik dari pekan kemarin?"
#
# Demi menjawab hal tersebut Anda melakukan kalkulasi sederhana dengan tahapan berikut:
#
# * Membuat kolom baru yang berisi jumlah kasus baru dalam satu pekan sebelumnya. Kolom ini diberi nama **jumlah_pekanlalu**.
# * Mengganti nilai **NaN** pada kolom **jumlah_pekanlalu** dengan nilai **0**
# * Melakukan komparasi antara kolom **jumlah** dengan kolom **jumlah_pekanlalu**. Hasil komparasi ini disimpan dalam kolom baru dengan nama **lebih_baik**, isinya adalah **True** apabila jumlah kasus baru pekan ini lebih rendah dibandingkan jumlah kasus pekan lalu
#
# Lengkapilah baris predefined kode yang diberikan untuk mengerjakan tahapan yang telah Anda rencanakan! Anda akan menggunakan method **shift()** untuk membuat kolom **jumlah_pekanlalu**. Inspeksi hasil pekerjaan Anda dengan menggunakan **head(10)**!

# %%
cov_jabar_pekanan['jumlah_pekanlalu'] = cov_jabar_pekanan['jumlah'].shift().replace(np.nan, 0).astype(np.int)
cov_jabar_pekanan['lebih_baik'] = cov_jabar_pekanan['jumlah'] < cov_jabar_pekanan['jumlah_pekanlalu']

print('Sepuluh data teratas:\n', cov_jabar_pekanan.head(10))
# Out:
# Sepuluh data teratas:
#     tahun  pekan_ke  jumlah  jumlah_pekanlalu  lebih_baik
# 0   2020        10       7                 0       False
# 1   2020        11       5                 7        True
# 2   2020        12      52                 5       False
# 3   2020        13     104                52       False
# 4   2020        14     122               104       False
# 5   2020        15     235               122       False
# 6   2020        16     277               235       False
# 7   2020        17     216               277        True
# 8   2020        18     156               216        True
# 9   2020        19     367               156       False

# %% [markdown]
# ### **Membuat Bar Chart**
# Anda sungguh luar biasa! Dengan menggunakan data hasil perhitungan tersebut maka sekarang Anda dapat membuat bar-chat penambahan kasus pekanan yang ditambahkan informasi baru untuk menjawab pertanyaan: **"Apakah pekan ini lebih baik?"**
#
# Salin dan jalankan kode berikut di konsol Anda!

# %%
import matplotlib.pyplot as plt

plt.clf()
fig, ax = plt.subplots(figsize=(10,5))
ax.bar(data=cov_jabar_pekanan, x='pekan_ke', height='jumlah',
       color=['mediumseagreen' if x is True else 'salmon' for x in cov_jabar_pekanan['lebih_baik']])
fig.suptitle('Kasus Pekanan Positif COVID-19 di Jawa Barat',
             y=1.00, fontsize=16, fontweight='bold', ha='center')
ax.set_title('Kolom hijau menunjukan penambahan kasus baru lebih sedikit dibandingkan satu pekan sebelumnya',
             fontsize=12)
ax.set_xlabel('')
ax.set_ylabel('Jumlah kasus')
ax.text(1, -0.1, 'Sumber data: covid.19.go.id', color='blue',
ha='right', transform=ax.transAxes)

plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Pola dan Dinamika**
# Ada yang akhirnya sembuh, namun tak sedikit pula yang meninggal akibat COVID-19. Sementara itu penambahan kasus baru terus terjadi di masyarakat. Hal ini mungkin memicu pertanyaan lain di diri Anda: "Hingga saat ini ada berapa kasus yang masih aktif?"
#
# Aktif dalam artian sedang dalam perawatan atau isolasi.
#
# Informasi ini sebenarnya telah disediakan di dalam respon API covid19.go.id yang Anda minta. Namun tidak ada salahnya jika Anda mencoba menghitungnya sendiri, apakah Anda setuju?
#
# Jumlah kasus aktif dapat dihitung dengan cara mengurangi jumlah akumulasi positif dengan jumlah akumulasi sembuh dan jumlah akumulasi meninggal. Anda dapat menggunakan method **cumsum()** untuk menghitung nilai akumulasi dari suatu vektor numerik. Lengkapilah baris kode berikut untuk menghitung jumlah akumulasi kasus aktif, kasus sembuh, dan kasus meninggal!

# %%
cov_jabar_akumulasi = cov_jabar_tidy[['tanggal']].copy()
cov_jabar_akumulasi['akumulasi_aktif'] = (cov_jabar_tidy['kasus_baru'] - cov_jabar_tidy['sembuh'] - cov_jabar_tidy['meninggal']).cumsum()
cov_jabar_akumulasi['akumulasi_sembuh'] = cov_jabar_tidy['sembuh'].cumsum()
cov_jabar_akumulasi['akumulasi_meninggal'] = cov_jabar_tidy['meninggal'].cumsum()
cov_jabar_akumulasi.tail()
# Out:
#        tanggal  akumulasi_aktif  akumulasi_sembuh  akumulasi_meninggal
# 346 2021-02-11            27818            141779                 2097
# 347 2021-02-12            26913            143362                 2102
# 348 2021-02-13            26164            145845                 2104
# 349 2021-02-14            25347            147539                 2108
# 350 2021-02-15            25024            148804                 2113

# %% [markdown]
# ### **Membuat Line Chart**
# Sekarang cobalah Anda buat line-chart pola kasus aktif dengan menggunakan method **plot** pada **ax**

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

plt.clf()
fig, ax = plt.subplots(figsize=(10,5))
ax.plot('tanggal', 'akumulasi_aktif', data=cov_jabar_akumulasi, lw=2)

ax.set_title('Akumulasi aktif COVID-19 di Jawa Barat',fontsize=22)
ax.set_xlabel('')
ax.set_ylabel('Akumulasi aktif')
ax.text(1, -0.1, 'Sumber data: covid.19.go.id', color='blue',
        ha='right', transform=ax.transAxes)

ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))

plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Kabar Buruk dan Kabar Baik**
# Sebagai penutup analisis dalam proyek ini Anda diminta untuk membuat grafik komparasi antara akumulasi kasus aktif, kasus sembuh, dan kasus meninggal.
#
# Ada dua pilihan cara yang dapat Anda tempuh untuk membuat grafik tersebut:
#
# 1. Menggunakan data frame **cov_jabar_akumulasi**, kemudian langsung melakukan line plot dan memilih warna garis yang sesuai untuk membedakan; atau
# 2. Menggunakan **ax.plot()** dan mengisikan kolom-kolom yang masing-masingnya menjadi x dan y dengan **data=cov_jabar_akumulasi**, dan kemudian menset warna berbeda untuk ketiga line plot.
#
# Anda akan diminta untuk menempuh cara nomor 1. Ketik True pada konsol jika Anda setuju!

# %% [markdown]
# ### **Tahap Terakhir**
# Anda hampir selesai! Pada tahap terakhir ini Anda cukup salin dan jalankan baris kode berikut di konsol untuk membuat grafik komparasi antara akumulasi kasus aktif, kasus sembuh dan kasus meninggal:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

plt.clf()
fig, ax = plt.subplots(figsize=(10,5))
cov_jabar_akumulasi.plot(x='tanggal', kind='line', ax=ax, lw=3,
                         color=['salmon', 'slategrey', 'olivedrab'])

ax.set_title('Dinamika Kasus COVID-19 di Jawa Barat',
             fontsize=22)
ax.set_xlabel('')
ax.set_ylabel('Akumulasi aktif')
ax.text(1, -0.1, 'Sumber data: covid19.go.id', color='blue',
        ha='right', transform=ax.transAxes)

ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b'))

plt.grid()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Penutup**

# %% [markdown]
# ### **Kesimpulan & Penutup**
# Selamat Anda telah menyelesaikan proyek analisis COVID-19 ini! Anda telah berhasil **melakukan impor data melalui API**, **melakukan transformasi data**, serta **membuat visualisasi** untuk mengkomunikasikan hasil analisis data tentang COVID-19.
#
# Anda dipersilakan untuk selanjutnya mengembangkan analisis dengan cara mengambil studi kasus provinsi lain atau bahkan melakukan komparasi antar provinsi.
